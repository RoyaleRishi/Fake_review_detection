# %% [markdown]
# #### Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
import re
import string
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Inserting Dataset

# %%
data = pd.read_csv("deceptive-opinion.csv")
data = data.rename(columns={"deceptive":"label"})

# %%
data.head(5)
# Out:
#       label   hotel  polarity       source  \
# 0  truthful  conrad  positive  TripAdvisor
# 1  truthful   hyatt  positive  TripAdvisor
# 2  truthful   hyatt  positive  TripAdvisor
# 3  truthful    omni  positive  TripAdvisor
# 4  truthful   hyatt  positive  TripAdvisor
#
#                                                 text
# 0  We stayed for a one night getaway with family ...
# 1  Triple A rate with upgrade to view room was le...
# 2  This comes a little late as I'm finally catchi...
# 3  The Omni Chicago really delivers on all fronts...
# 4  I asked for a high floor away from the elevato...

# %% [markdown]
# #### Shuffling Dataset

# %%
data = data.sample(frac = 1)

# %%
data.head(10)
# Out:
#           label             hotel  polarity       source  \
# 587   deceptive          hardrock  positive        MTurk
# 1036   truthful          hardrock  negative          Web
# 1320  deceptive          homewood  negative        MTurk
# 883    truthful          homewood  negative          Web
# 768   deceptive            palmer  positive        MTurk
# 1356  deceptive          homewood  negative        MTurk
# 1526  deceptive  intercontinental  negative        MTurk
# 699   deceptive           sofitel  positive        MTurk
# 843    truthful            conrad  negative          Web
# 165    truthful        ambassador  positive  TripAdvisor
#
#                                                    text
# 587   After searching for the perfect hotel for my C...
# 1036  Move beyond the rock theme and it's an average...
# 1320  I went to the Homewood Suites in Chicago which...
# 883   While the parking service was great - the fron...
# 768   An excellent vacation destination. Clean rooms...
# 1356  Not worth the price! I had the unfortunate exp...
# 1526  The International Chicago Magnificent Mile is ...
# 699   Best hotel in an excellent location I stayed a...
# 843   We've stayed here before but this time around ...
# 165   In a very nice location close to shopping and ...

# %% [markdown]
# #### Dropping attributes that are not needed

# %%
data = data.drop(["hotel", "source"], axis = 1)
data.head(10)
# Out:
#           label  polarity                                               text
# 587   deceptive  positive  After searching for the perfect hotel for my C...
# 1036   truthful  negative  Move beyond the rock theme and it's an average...
# 1320  deceptive  negative  I went to the Homewood Suites in Chicago which...
# 883    truthful  negative  While the parking service was great - the fron...
# 768   deceptive  positive  An excellent vacation destination. Clean rooms...
# 1356  deceptive  negative  Not worth the price! I had the unfortunate exp...
# 1526  deceptive  negative  The International Chicago Magnificent Mile is ...
# 699   deceptive  positive  Best hotel in an excellent location I stayed a...
# 843    truthful  negative  We've stayed here before but this time around ...
# 165    truthful  positive  In a very nice location close to shopping and ...

# %% [markdown]
# #### Resetting Index

# %%
data.reset_index(inplace = True)
data.drop(["index"], axis = 1, inplace = True)
data.head(5)
# Out:
#        label  polarity                                               text
# 0  deceptive  positive  After searching for the perfect hotel for my C...
# 1   truthful  negative  Move beyond the rock theme and it's an average...
# 2  deceptive  negative  I went to the Homewood Suites in Chicago which...
# 3   truthful  negative  While the parking service was great - the fron...
# 4  deceptive  positive  An excellent vacation destination. Clean rooms...

# %% [markdown]
# #### Checking for NULL values

# %%
data.isnull().sum()
# Out:
# label       0
# polarity    0
# text        0
# dtype: int64

# %% [markdown]
# #### Grouping the data based on polarity to identify skew in data

# %%
groupedReviews = data.groupby("polarity").label.value_counts()
groupedReviews
# Out:
# polarity  label
# negative  deceptive    400
#           truthful     400
# positive  deceptive    400
#           truthful     400
# Name: label, dtype: int64

# %% [markdown]
# Note - There is minimal skew, Therefore we can proceed without any adjustments

# %% [markdown]
# #### Eliminating polarity as there is no skew

# %%
data.drop(["polarity"], axis = 1, inplace = True)

# %%
data.head(5)
# Out:
#        label                                               text
# 0  deceptive  After searching for the perfect hotel for my C...
# 1   truthful  Move beyond the rock theme and it's an average...
# 2  deceptive  I went to the Homewood Suites in Chicago which...
# 3   truthful  While the parking service was great - the fron...
# 4  deceptive  An excellent vacation destination. Clean rooms...

# %% [markdown]
# #### Renaming label as 0 and 1

# %%
dummy = pd.get_dummies(data['label'])
dummy.head(5)
# Out:
#    deceptive  truthful
# 0          1         0
# 1          0         1
# 2          1         0
# 3          0         1
# 4          1         0

# %%
data = pd.concat((data, dummy), axis = 1)
data.head(5)
# Out:
#        label                                               text  deceptive  \
# 0  deceptive  After searching for the perfect hotel for my C...          1
# 1   truthful  Move beyond the rock theme and it's an average...          0
# 2  deceptive  I went to the Homewood Suites in Chicago which...          1
# 3   truthful  While the parking service was great - the fron...          0
# 4  deceptive  An excellent vacation destination. Clean rooms...          1
#
#    truthful
# 0         0
# 1         1
# 2         0
# 3         1
# 4         0

# %%
data.drop(["label"], axis = 1, inplace = True)
data.drop(["deceptive"], axis = 1, inplace = True)
data = data.rename(columns = {"truthful":"label"})
data.head(5)
# Out:
#                                                 text  label
# 0  After searching for the perfect hotel for my C...      0
# 1  Move beyond the rock theme and it's an average...      1
# 2  I went to the Homewood Suites in Chicago which...      0
# 3  While the parking service was great - the fron...      1
# 4  An excellent vacation destination. Clean rooms...      0

# %% [markdown]
# #### Removing Last 10 rows for testing

# %%
data.shape
# Out:
# (1600, 2)

# %%
data_for_manualTesting = data.tail(10)
for i in range(1599,1589,-1):
    data.drop([i], axis = 0, inplace = True)

# %%
data_for_manualTesting.reset_index(inplace = True)
data_for_manualTesting.drop(["index"], axis = 1, inplace = True)
data_for_manualTesting.head(10)
# Out:
#                                                 text  label
# 0  The Sheraton Chicago Hotel and Towers is a mag...      0
# 1  Thank god I got this hotel through priceline. ...      1
# 2  The Hilton Chicago is one of the best Hotels I...      0
# 3  so my sweetie lures me out under the guise of ...      1
# 4  As a frequent traveler for both business and p...      0
# 5  It has been a couple of years since I stayed h...      1
# 6  First of all when you check in the check in pr...      0
# 7  They allowed parties to go on all night and bo...      1
# 8  My stay at the Homewood Suites in downtown Chi...      0
# 9  The Talbott Hotel was very classy, professiona...      0

# %% [markdown]
# ## Defining Independent and Dependent Variables

# %%
x = data["text"] #independent
y = data["label"] #dependent

x_manual = data_for_manualTesting["text"]
y_manual = data_for_manualTesting["label"]

# %%
x
# Out:
# 0       After searching for the perfect hotel for my C...
# 1       Move beyond the rock theme and it's an average...
# 2       I went to the Homewood Suites in Chicago which...
# 3       While the parking service was great - the fron...
# 4       An excellent vacation destination. Clean rooms...
#                               ...
# 1585    Triple A rate with upgrade to view room was le...
# 1586    It was my first time to visit Chicago and I wo...
# 1587    I recently was in Chicago on business and chos...
# 1588    I had a wonderful time at the James Hotel whil...
# 1589    Overpriced is the best word to describe the Co...
# Name: text, Length: 1590, dtype: object

# %%
x_manual
# Out:
# 0    The Sheraton Chicago Hotel and Towers is a mag...
# 1    Thank god I got this hotel through priceline. ...
# 2    The Hilton Chicago is one of the best Hotels I...
# 3    so my sweetie lures me out under the guise of ...
# 4    As a frequent traveler for both business and p...
# 5    It has been a couple of years since I stayed h...
# 6    First of all when you check in the check in pr...
# 7    They allowed parties to go on all night and bo...
# 8    My stay at the Homewood Suites in downtown Chi...
# 9    The Talbott Hotel was very classy, professiona...
# Name: text, dtype: object

# %% [markdown]
# # Bidirectional LSTM

# %%
import tensorflow as tf

# %%
tf.__version__
# Out:
# '2.8.0'

# %%
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.preprocessing.text import one_hot
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Bidirectional
from tensorflow.keras.layers import Dropout

# %%
### Vocabulary size
voc_size=5000

# %% [markdown]
# ### Onehot Representation

# %%
messages= x.copy()
test_messages = x_manual.copy()

# %%
messages[1]
# Out:
# "Move beyond the rock theme and it's an average hotel with a good location. Room was unbearably hot and the controls on the wall did nothing. Thank goodness the window opened or we'd have been cooked alive. That of course let in all the noise from Michigan Ave. This combined with our neighbors door slamming against their thrown door lock every 30 seconds made for a lively setting. Room was stuffy too. Burn marks on carpet lead me to believe nasty smokers had occupied room on many occasions. Wife happy w/ Aveda in bath. Base bar was good with great service and well made drinks tho pricey.\n"

# %%
import nltk
import re
from nltk.corpus import stopwords

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /Users/rishi/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
corpus = []
for i in range(0, len(messages)):
    review = re.sub('[^a-zA-Z]', ' ', messages[i])
    review = review.lower()
    review = review.split()
    
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    corpus.append(review)
    
ps_manual = PorterStemmer()
corpus_manual = []
for i in range(0, len(test_messages)):
    review_manual = re.sub('[^a-zA-Z]', ' ', test_messages[i])
    review_manual = review_manual.lower()
    review_manual = review_manual.split()
    
    review_manual = [ps_manual.stem(word) for word in review_manual if not word in stopwords.words('english')]
    review_manual = ' '.join(review_manual)
    corpus_manual.append(review_manual)

# %%
onehot_repr=[one_hot(words,voc_size)for words in corpus] 
onehot_test = [one_hot(words,voc_size)for words in corpus_manual] 
onehot_repr
# Out:
# [[3909,
#   887,
#   4287,
#   316,
#   3369,
#   2148,
#   3364,
#   1105,
#   4589,
#   398,
#   4287,
#   4287,
#   4357,
#   958,
#   2845,
#   4287,
#   2602,
#   796,
#   2986,
#   58,
#   2606,
#   4654,
#   4287,
#   2131,
#   700,
#   202,
#   308,
#   3759,
#   2251,
#   1434,
#   4565,
#   1645,
#   2314,
#   4673,
#   3767,
#   1787,
#   3569,
#   3619,
#   1320,
#   1919,
#   1488,
#   952,
#   2143,
#   3142,
#   565,
#   4373,
#   2597,
#   3767,
#   1101,
#   1401,
#   1282,
#   1457,
#   2159,
#   316,
#   3593,
#   3116,
#   986,
#   3926,
#   4104,
#   2716,
#   2613,
#   4700,
#   4021,
#   3995,
#   4673,
#   2716,
#   4166,
#   403,
#   4641,
#   239,
#   2111,
#   3657,
#   4897,
#   4878,
#   4295,
#   633,
#   272,
#   4839,
#   2695,
#   1867,
#   3941,
#   4027,
#   19,
#   4589,
#   398,
#   4804,
#   4078,
#   3600,
#   2378,
#   4145,
#   197,
#   4261,
#   3302,
#   2504,
#   3688,
#   4331,
#   958,
#   1616,
#   1780],
#  [4102,
#   3196,
#   398,
#   2984,
#   549,
#   4287,
#   1930,
#   2538,
#   3767,
#   414,
#   4637,
#   3328,
#   766,
#   1484,
#   686,
#   1930,
#   2008,
#   1101,
#   2811,
#   3336,
#   2019,
#   239,
#   688,
#   607,
#   1542,
#   3333,
#   3982,
#   1401,
#   4017,
#   4800,
#   1401,
#   3562,
#   3898,
#   2114,
#   3792,
#   3186,
#   46,
#   3767,
#   670,
#   4602,
#   1241,
#   4731,
#   2476,
#   1540,
#   2162,
#   412,
#   3955,
#   3767,
#   4078,
#   1595,
#   4022,
#   4061,
#   2289,
#   3686,
#   1905,
#   4472,
#   4104,
#   1930,
#   4282,
#   3995,
#   4032,
#   3792,
#   453,
#   4629,
#   303],
#  [3926,
#   3440,
#   1550,
#   316,
#   2256,
#   883,
#   3316,
#   4287,
#   1527,
#   2976,
#   492,
#   4287,
#   3902,
#   811,
#   3440,
#   1550,
#   492,
#   4287,
#   3830,
#   2288,
#   892,
#   3767,
#   3767,
#   4865,
#   1804,
#   4287,
#   3683,
#   2043,
#   4605,
#   811,
#   3767,
#   4865,
#   2043,
#   1102,
#   1906,
#   4287,
#   3002,
#   1320,
#   688,
#   892,
#   4630,
#   3041,
#   4287,
#   3982,
#   633,
#   4630,
#   2862,
#   2571,
#   3767,
#   2729,
#   4192,
#   4287,
#   492,
#   3995,
#   293,
#   2729,
#   633,
#   2847,
#   2025,
#   4287,
#   2014,
#   4865,
#   1804,
#   4568,
#   2014,
#   4865,
#   1804,
#   2014,
#   3750,
#   4865,
#   1804,
#   36,
#   1042,
#   4192,
#   3294,
#   554,
#   1686,
#   4287,
#   4436,
#   2772,
#   590,
#   2371,
#   4287,
#   554,
#   19,
#   4118,
#   1356,
#   4287,
#   2602],
#  [4211,
#   3995,
#   4282,
#   1645,
#   619,
#   1172,
#   2340,
#   4540,
#   1821,
#   3514,
#   633,
#   4839,
#   1162,
#   3767,
#   3926,
#   1602,
#   1821,
#   633,
#   1488,
#   4211,
#   1645,
#   619,
#   3798,
#   4104,
#   1162,
#   4654,
#   4211,
#   485,
#   1219,
#   1821,
#   2845,
#   368,
#   2976,
#   4857,
#   2272,
#   1394],
#  [2863,
#   3146,
#   1071,
#   3645,
#   3767,
#   4078,
#   3370,
#   4593,
#   1073,
#   2538,
#   1689,
#   4319,
#   3142,
#   2314,
#   4005,
#   2992,
#   4599,
#   1488,
#   4027,
#   19,
#   4118,
#   4865,
#   3669,
#   3060],
#  [3914,
#   3729,
#   2563,
#   1730,
#   4804,
#   883,
#   3440,
#   1550,
#   4012,
#   316,
#   4804,
#   4531,
#   3146,
#   3992,
#   2845,
#   397,
#   3357,
#   3926,
#   42,
#   288,
#   4287,
#   2231,
#   1315,
#   775,
#   4251,
#   995,
#   861,
#   1804,
#   2516,
#   4211,
#   3273,
#   1579,
#   3729,
#   1884,
#   1320,
#   1869,
#   4211,
#   1999,
#   4839,
#   4804,
#   1315,
#   4211,
#   2845,
#   2315,
#   2314,
#   3370,
#   3758,
#   4203,
#   2690,
#   4698,
#   1804,
#   1488,
#   310,
#   3794,
#   1874,
#   3941,
#   2084,
#   3991,
#   2043,
#   4787,
#   36,
#   3491,
#   4654,
#   3767,
#   1787,
#   2518,
#   3041,
#   1686,
#   3280,
#   4801,
#   1821,
#   1213,
#   4903,
#   389,
#   2315,
#   3941,
#   4568,
#   3041,
#   3767,
#   3370,
#   4593,
#   1804,
#   674,
#   317,
#   1402,
#   4201,
#   2381,
#   1686,
#   3146,
#   2811,
#   1556,
#   2381,
#   1821,
#   4078,
#   2142,
#   1869,
#   1102,
#   3192,
#   2041,
#   2019,
#   3505,
#   2230,
#   4386,
#   2976,
#   1141,
#   29,
#   4287,
#   3767,
#   2516,
#   3794,
#   3438,
#   4668,
#   1893,
#   3914,
#   2420,
#   1821,
#   2956,
#   3946,
#   4715,
#   2602,
#   2516,
#   1557,
#   3596,
#   1484,
#   1473,
#   217,
#   2956,
#   3390,
#   549,
#   3390,
#   3413,
#   4355,
#   4335,
#   3610,
#   1281,
#   3600,
#   4287,
#   2003,
#   4287,
#   4012,
#   4145,
#   2111,
#   4695,
#   633,
#   861,
#   3147,
#   3600,
#   2639,
#   1821,
#   3224,
#   3767,
#   3413,
#   3645,
#   2976,
#   1215,
#   4287,
#   1215,
#   3811,
#   3729,
#   4350,
#   4865,
#   4287,
#   316,
#   2976,
#   397,
#   3357,
#   1686,
#   42,
#   288,
#   2956,
#   4804,
#   272,
#   1455,
#   4078,
#   4287,
#   4690,
#   1439],
#  [4145,
#   316,
#   2283,
#   1805,
#   4938,
#   2326,
#   3413,
#   4912,
#   2278,
#   2606,
#   2173,
#   4154,
#   980,
#   2007,
#   4917,
#   1307,
#   120,
#   4287,
#   449,
#   2958,
#   302,
#   3902,
#   2592,
#   3767,
#   4841,
#   1390,
#   2153,
#   633,
#   3351,
#   3767,
#   1356,
#   2315,
#   958,
#   988,
#   2315,
#   3729,
#   4532,
#   717,
#   4287,
#   1836,
#   4679,
#   4841,
#   3767,
#   1821,
#   2845,
#   19,
#   4804],
#  [272,
#   4287,
#   2863,
#   2538,
#   4804,
#   2837,
#   316,
#   1398,
#   3029,
#   3942,
#   3776,
#   3364,
#   3226,
#   2297,
#   590,
#   4917,
#   3776,
#   4752,
#   3657,
#   4177,
#   2504,
#   1077,
#   3767,
#   1645,
#   619,
#   4620,
#   1076,
#   2314,
#   2992,
#   3767,
#   3995,
#   1320,
#   1930,
#   3767,
#   3645,
#   3729,
#   1930,
#   1804,
#   1412,
#   3767,
#   3431,
#   565,
#   2837,
#   1930,
#   2504,
#   3883,
#   4992,
#   274,
#   4804,
#   2837,
#   4536,
#   3941,
#   3669,
#   316],
#  [4804,
#   3941,
#   3600,
#   1241,
#   463,
#   4679,
#   3995,
#   2314,
#   2084,
#   1070,
#   4533,
#   515,
#   3074,
#   3016,
#   3767,
#   4287,
#   3538,
#   3995,
#   753,
#   4104,
#   3767,
#   1836,
#   1804,
#   4177,
#   1506,
#   861,
#   1686,
#   3436,
#   4287,
#   3236,
#   2314,
#   3342,
#   2378,
#   2312,
#   1849,
#   4261,
#   1159,
#   2893,
#   2563,
#   2101,
#   2362,
#   4785,
#   3767,
#   2041,
#   3230,
#   713,
#   1897,
#   1776,
#   1051,
#   4806,
#   2923,
#   3192,
#   3619,
#   3767,
#   3645,
#   3729,
#   3332,
#   1368,
#   763,
#   3683,
#   4238,
#   2591,
#   4287,
#   4923,
#   3280,
#   4312,
#   3466,
#   1897,
#   2314,
#   4095,
#   3729,
#   699,
#   4287,
#   4804,
#   3757,
#   3351,
#   4287,
#   4078,
#   4282,
#   3892],
#  [3370,
#   2538,
#   156,
#   69,
#   3671,
#   2760,
#   1320,
#   700,
#   2219,
#   1390,
#   4287,
#   630,
#   3671,
#   1053,
#   3377,
#   2147,
#   3767,
#   2173,
#   3671,
#   453,
#   1557,
#   3402,
#   2504,
#   4620,
#   3192,
#   4093,
#   453,
#   4865,
#   2008,
#   4620,
#   2219,
#   1886,
#   201,
#   1930,
#   69,
#   2760],
#  [4804,
#   1548,
#   4839,
#   2555,
#   4331,
#   3619,
#   938,
#   1283,
#   3792,
#   3767,
#   1877,
#   517,
#   1241,
#   707,
#   4989,
#   3941,
#   4804,
#   590,
#   2208,
#   4633,
#   4282,
#   2201,
#   4917,
#   3941,
#   2345,
#   4287],
#  [2357,
#   2505,
#   4606,
#   316,
#   1102,
#   4804,
#   2769,
#   156,
#   4012,
#   3874,
#   4931,
#   4287,
#   2538,
#   3198,
#   1356,
#   2299,
#   3671,
#   4743,
#   3874,
#   4668,
#   3369,
#   4250,
#   4386,
#   4787,
#   272,
#   4335,
#   3902,
#   4287,
#   351,
#   3645,
#   1393,
#   3657,
#   517,
#   2314,
#   1073,
#   3256,
#   808,
#   144,
#   3507,
#   1320,
#   4177,
#   2138,
#   2378,
#   3910,
#   4787,
#   4752,
#   4787,
#   3507,
#   3364,
#   3280,
#   3767,
#   777,
#   696,
#   4620,
#   1219,
#   361,
#   3767,
#   4177,
#   986,
#   483,
#   2403,
#   4282,
#   696,
#   3926,
#   3577,
#   2016,
#   4287,
#   251,
#   2378,
#   2522,
#   1062,
#   3390,
#   1436,
#   1320,
#   4282,
#   2751,
#   3596,
#   1320,
#   2760,
#   1002,
#   3499,
#   3370,
#   4032,
#   4839,
#   3413,
#   4037,
#   3926,
#   4787,
#   4282,
#   3941,
#   4287,
#   19,
#   3671,
#   1370,
#   1686,
#   2585,
#   3892],
#  [3942,
#   4804,
#   2837,
#   316,
#   1398,
#   3029,
#   1548,
#   4839,
#   4989,
#   4929,
#   19,
#   3472,
#   403,
#   1085,
#   4717,
#   1550,
#   2413,
#   4042,
#   1919,
#   2584,
#   3892,
#   4211,
#   2159,
#   2956,
#   3786,
#   3767,
#   4717,
#   4896,
#   578,
#   3152,
#   4377,
#   87,
#   892,
#   2378,
#   3767,
#   2084,
#   4165,
#   1421,
#   1488,
#   1424,
#   688,
#   3767,
#   3657,
#   4582,
#   2131,
#   457,
#   2299,
#   1628,
#   3729,
#   4896,
#   2797,
#   2783,
#   3332,
#   3942,
#   1283,
#   1919,
#   323,
#   3767,
#   274,
#   3645,
#   633,
#   2331,
#   3700,
#   2378,
#   3767,
#   4421,
#   1919,
#   3273,
#   2845,
#   4804,
#   4287,
#   4436,
#   2602,
#   2315,
#   4839],
#  [1804,
#   4540,
#   1821,
#   3767,
#   4568,
#   2986,
#   4211,
#   4287,
#   1548,
#   3941,
#   1866,
#   2616,
#   3941,
#   515,
#   491,
#   4568,
#   688,
#   3767,
#   2986,
#   2215,
#   709,
#   1356,
#   3217,
#   2497,
#   3116,
#   3226,
#   3116,
#   707,
#   633,
#   4287,
#   3902,
#   709,
#   2420,
#   2497,
#   3116,
#   4742,
#   3936,
#   1686,
#   709,
#   36,
#   3963,
#   2101,
#   1337,
#   811,
#   4536,
#   709,
#   3071,
#   3657,
#   4202,
#   2482,
#   3995,
#   2314,
#   4419,
#   1779,
#   3273,
#   4331,
#   3661,
#   4838,
#   316,
#   2769,
#   4659,
#   3671,
#   2716,
#   4489],
#  [4804,
#   316,
#   3941,
#   3226,
#   3910,
#   4804,
#   316,
#   883,
#   3413,
#   3688,
#   4804,
#   883,
#   367,
#   4804,
#   1382,
#   2259,
#   861,
#   377,
#   883,
#   4817,
#   3645,
#   1645,
#   619,
#   2314,
#   3370,
#   316,
#   3021,
#   2337,
#   4742,
#   1550,
#   4436,
#   883,
#   528,
#   3188,
#   1928,
#   316,
#   883,
#   1439,
#   2231,
#   942,
#   883,
#   367,
#   316,
#   3767,
#   4032,
#   3339,
#   3729,
#   3767,
#   4699,
#   3370,
#   95,
#   404,
#   2733,
#   2684,
#   2131,
#   4848,
#   4839,
#   1867,
#   3596,
#   1821,
#   1804,
#   4787,
#   3188,
#   1919,
#   4287,
#   1686,
#   316,
#   1804,
#   883,
#   4975,
#   4287,
#   3281,
#   2956,
#   3671],
#  [4929,
#   1836,
#   4839,
#   2986,
#   883,
#   316,
#   1283,
#   3767,
#   492,
#   1215,
#   2459,
#   837,
#   3830,
#   1101,
#   2159,
#   156,
#   308,
#   2986,
#   3792,
#   1286,
#   3669,
#   2423,
#   1003,
#   1283,
#   2007,
#   4787,
#   1065,
#   1039,
#   4287,
#   892,
#   2331,
#   4742,
#   2505,
#   3700,
#   2845,
#   278,
#   3757,
#   1804,
#   546,
#   573,
#   4093,
#   3767,
#   358,
#   3723,
#   1101,
#   1401,
#   2789,
#   3767,
#   3133,
#   633,
#   3029,
#   2006,
#   4379,
#   1286,
#   3830,
#   766,
#   3767,
#   4211,
#   619,
#   3863,
#   3700,
#   4287,
#   4890,
#   4589,
#   2111,
#   3767,
#   4417,
#   4421,
#   1550,
#   1283,
#   1053,
#   2368,
#   415,
#   2845,
#   4211,
#   633,
#   4211,
#   437,
#   4037,
#   856,
#   633,
#   699,
#   3700,
#   4192,
#   496,
#   3767,
#   3680,
#   3657,
#   1684,
#   1919,
#   4192,
#   1686,
#   4357,
#   3767,
#   4054,
#   4102,
#   586,
#   4574,
#   2616,
#   2043,
#   3680,
#   3657,
#   4192,
#   714,
#   3767,
#   718,
#   4264,
#   4804,
#   2462,
#   4379,
#   3767,
#   4667,
#   4060,
#   3767,
#   633,
#   3657,
#   688,
#   4379,
#   3767,
#   4762,
#   3657,
#   328,
#   4593,
#   3767,
#   3729,
#   2368,
#   4792,
#   404,
#   3540,
#   4762,
#   1347,
#   2362,
#   3909,
#   619,
#   4379,
#   1286,
#   837,
#   724,
#   3688,
#   413,
#   2847,
#   2592,
#   1286,
#   4177,
#   1102,
#   4060,
#   2924,
#   3286,
#   3002,
#   3377,
#   3989,
#   105,
#   578,
#   3748,
#   4787,
#   4211,
#   4127,
#   4773,
#   3786,
#   688,
#   718,
#   1197,
#   2692,
#   3671,
#   3941,
#   1583,
#   3767,
#   4536,
#   3941,
#   316,
#   1286,
#   4083,
#   4804,
#   323,
#   4287,
#   3688,
#   2956,
#   2538,
#   883,
#   316,
#   4865,
#   845,
#   3133,
#   3029,
#   3767,
#   3671,
#   3688,
#   2956,
#   3273,
#   4060,
#   3767,
#   4032,
#   2956,
#   2482,
#   3995,
#   4831,
#   316,
#   883],
#  [501,
#   4012,
#   316,
#   4282,
#   4804,
#   2256,
#   703,
#   1658,
#   4417,
#   4287,
#   501,
#   2602,
#   2295,
#   4804,
#   700,
#   3767,
#   433,
#   3729,
#   2602,
#   2516,
#   450,
#   3074,
#   3864,
#   2846,
#   4093,
#   4287,
#   492,
#   3438,
#   1356,
#   2818,
#   2602,
#   1018,
#   3892,
#   2845,
#   19,
#   4211,
#   3741,
#   4012,
#   3060,
#   918,
#   384,
#   2818,
#   1906,
#   3619,
#   4287,
#   4551,
#   4865,
#   2339,
#   4211,
#   4301,
#   3113,
#   14,
#   2299,
#   2256,
#   3892,
#   3767,
#   1390,
#   700,
#   990,
#   4282,
#   752,
#   517,
#   3657,
#   3436,
#   4282,
#   2159,
#   1686,
#   703,
#   1658,
#   4042,
#   302,
#   938,
#   4663,
#   4282,
#   1919,
#   4108,
#   4787,
#   703,
#   4282,
#   1839,
#   367,
#   3674,
#   4698],
#  [1511,
#   1991,
#   707,
#   3782,
#   124,
#   3767,
#   1390,
#   4896,
#   861,
#   3952,
#   1159,
#   4212,
#   1373,
#   2314,
#   2522,
#   3466,
#   202,
#   3309,
#   272,
#   1919,
#   3782,
#   1570,
#   4078,
#   3230,
#   316,
#   1692,
#   124,
#   633,
#   4335,
#   4804,
#   1370,
#   796,
#   3767],
#  [3370,
#   4287,
#   2956,
#   1154,
#   4637,
#   3596,
#   4282,
#   3004,
#   1557,
#   4839,
#   2893,
#   3196,
#   4436,
#   2315,
#   3074,
#   3767,
#   3413,
#   1930,
#   4841,
#   4032,
#   4685,
#   3645,
#   1804,
#   2159,
#   3767,
#   2420,
#   2497,
#   3116,
#   942,
#   1356,
#   2845,
#   1804,
#   4412,
#   2976,
#   1261,
#   4177,
#   3370,
#   2602,
#   3413,
#   2184,
#   2159,
#   2314,
#   2992,
#   1488,
#   3910,
#   3941,
#   316,
#   3256,
#   699,
#   58,
#   3523,
#   397,
#   1610,
#   2845,
#   4145,
#   19,
#   4287],
#  [3337,
#   3390,
#   230,
#   4663,
#   3767,
#   4896,
#   1603,
#   4238,
#   3852,
#   1603,
#   2041,
#   2205,
#   2710,
#   1101,
#   2597,
#   4335,
#   1172,
#   3792,
#   1279,
#   3898,
#   3941,
#   3926,
#   4951,
#   4323,
#   4839,
#   2605,
#   62,
#   2380,
#   828,
#   777,
#   734,
#   4032,
#   1821,
#   1869,
#   714,
#   828,
#   4897,
#   2043,
#   1819,
#   4531,
#   688,
#   2164,
#   633,
#   2847,
#   3370,
#   2538,
#   58,
#   607,
#   3345,
#   2114,
#   4839,
#   778,
#   3926,
#   323,
#   4287,
#   4798,
#   3201,
#   3941,
#   150,
#   4804],
#  [4804,
#   4531,
#   4804,
#   3769,
#   4606,
#   2314,
#   2084,
#   4698,
#   1804,
#   191,
#   3767,
#   4865,
#   3370,
#   3146,
#   688,
#   3767,
#   4865,
#   1804,
#   2771,
#   3551,
#   1668,
#   2043,
#   3995,
#   3914,
#   3357],
#  [4804,
#   297,
#   633,
#   2533,
#   486,
#   4762,
#   1122,
#   316,
#   616,
#   2041,
#   856,
#   4654,
#   1050,
#   822,
#   1488,
#   4110,
#   729,
#   3907,
#   3395,
#   778,
#   3767,
#   192,
#   1122,
#   2143,
#   4220,
#   696,
#   1628,
#   4261,
#   2641,
#   3648,
#   3995,
#   1150,
#   1142,
#   431,
#   986,
#   590,
#   3767,
#   3645,
#   4791,
#   199,
#   4516,
#   517,
#   4379,
#   4879,
#   3340,
#   4732,
#   3657,
#   877,
#   4804,
#   4262],
#  [4667,
#   2956,
#   217,
#   4472,
#   892,
#   4012,
#   316,
#   4287,
#   2837,
#   58,
#   1642,
#   3858,
#   492,
#   29,
#   311,
#   218,
#   2504,
#   4319,
#   1235,
#   4012,
#   3316,
#   3767,
#   1600,
#   4762,
#   3359,
#   1169,
#   3316,
#   4791,
#   1393,
#   1412,
#   4104,
#   4801,
#   3508,
#   303,
#   3792,
#   517,
#   2335,
#   1990,
#   504,
#   4704,
#   3792,
#   2863,
#   2716,
#   633,
#   4839,
#   4641,
#   1804,
#   1686,
#   2710,
#   4801,
#   2760,
#   4389,
#   1438,
#   2604,
#   1598,
#   4767,
#   4335,
#   3643,
#   3431,
#   2229,
#   2845,
#   4145,
#   796],
#  [1862,
#   3231,
#   4287,
#   3671,
#   2402,
#   167,
#   4865,
#   1934,
#   4804,
#   29,
#   1511,
#   2613,
#   802,
#   2131,
#   3767,
#   2159,
#   1930,
#   1847,
#   308,
#   779,
#   1390,
#   1645,
#   2917,
#   2538,
#   106,
#   2340,
#   3729,
#   633,
#   2340,
#   2483,
#   350,
#   1402,
#   95,
#   2372,
#   2444,
#   3412,
#   3499,
#   4472,
#   1687,
#   3370,
#   201,
#   424,
#   565,
#   3198,
#   4027,
#   3645,
#   3669,
#   316,
#   1999,
#   590,
#   4005,
#   4804,
#   348,
#   1914,
#   19,
#   4804,
#   806],
#  [4804,
#   4839,
#   932,
#   4501,
#   4211,
#   4211,
#   1550,
#   3664,
#   1215,
#   2733,
#   2008,
#   633,
#   4264,
#   2043,
#   1506,
#   1710,
#   4731,
#   2923,
#   1886,
#   1839,
#   766,
#   95,
#   3006,
#   3928,
#   3767,
#   2008,
#   3910,
#   3394,
#   2472,
#   2043,
#   2043,
#   1730,
#   3757,
#   2608,
#   4287,
#   3645,
#   3060],
#  [4051,
#   3942,
#   3226,
#   4606,
#   316,
#   3280,
#   1072,
#   4804,
#   2139,
#   4972,
#   4287,
#   3671,
#   4083,
#   4492,
#   4917,
#   4847,
#   2345,
#   1320,
#   3645,
#   69,
#   2084,
#   3569,
#   201,
#   424,
#   69,
#   3942,
#   3041,
#   1821,
#   2956,
#   2483,
#   3995,
#   4673,
#   4951,
#   2738,
#   4917,
#   4287,
#   4145,
#   4804],
#  [4972,
#   4287,
#   633,
#   3326,
#   4287,
#   616,
#   4022,
#   4502,
#   4211,
#   2169,
#   4250,
#   251,
#   2378,
#   1598,
#   3767,
#   2516,
#   196,
#   3995,
#   4282,
#   1507,
#   3038,
#   3769,
#   3600,
#   4032,
#   3914,
#   3729,
#   3992,
#   1686,
#   3280,
#   3767,
#   197,
#   1401,
#   4287,
#   2314,
#   2863,
#   633,
#   4630,
#   2735,
#   1488,
#   2378,
#   3757,
#   861,
#   3600,
#   3892,
#   443,
#   4972,
#   4177,
#   3977,
#   4742,
#   2483,
#   616,
#   4992],
#  [2299,
#   3757,
#   4989,
#   3619,
#   4287,
#   4804,
#   4839,
#   3364,
#   633,
#   3910,
#   3729,
#   633,
#   4839,
#   2503,
#   2775,
#   4589,
#   1645,
#   619,
#   2865,
#   2143,
#   1804,
#   2114,
#   1919,
#   4261,
#   1558,
#   688,
#   3767,
#   688,
#   1631,
#   1142,
#   2256,
#   2801,
#   859,
#   2639,
#   785,
#   3246,
#   167,
#   1821,
#   3688,
#   2695,
#   1320,
#   2462,
#   4896,
#   3834,
#   1578,
#   3657,
#   4917,
#   1347,
#   95,
#   3041,
#   1668,
#   3309,
#   4287],
#  [4287,
#   4282,
#   2538,
#   2992,
#   2314,
#   4192,
#   1640,
#   2995,
#   367,
#   877,
#   3056,
#   3757,
#   2595,
#   2420,
#   4820,
#   4287,
#   3280,
#   590,
#   3767,
#   4032,
#   2201,
#   4917,
#   4731,
#   580,
#   1401,
#   766,
#   771,
#   1748,
#   766,
#   95,
#   2082,
#   1387,
#   1686,
#   3377,
#   3060,
#   2639,
#   159,
#   1821,
#   565,
#   1230,
#   1906,
#   4287,
#   201,
#   3741,
#   1401],
#  [3018,
#   1813,
#   3767,
#   4421,
#   4589,
#   398,
#   4287,
#   316,
#   2845,
#   217,
#   2845,
#   3438,
#   1717,
#   199,
#   3436,
#   3700,
#   4192,
#   3794,
#   796,
#   4212,
#   167,
#   4203,
#   3016,
#   2263,
#   4942,
#   4667,
#   3600,
#   3794,
#   3438,
#   1442],
#  [1730,
#   2857,
#   316,
#   2139,
#   4211,
#   2370,
#   4022,
#   1102,
#   4606,
#   2769,
#   4659,
#   2923,
#   2986,
#   2857,
#   316,
#   2139,
#   4211,
#   4287,
#   4654,
#   4427,
#   2293,
#   3767,
#   4421,
#   796,
#   4022,
#   4177,
#   3941,
#   3016,
#   2314,
#   757,
#   4022,
#   3852,
#   1142,
#   3767,
#   4667,
#   4071,
#   1686,
#   4804,
#   42,
#   288,
#   326,
#   2084,
#   1303,
#   4804,
#   4839,
#   3910,
#   2847,
#   4536,
#   3004,
#   1906,
#   4865,
#   463,
#   4287,
#   554,
#   4804,
#   4287],
#  [1394,
#   1934,
#   4606,
#   2517,
#   367,
#   3031,
#   316,
#   688,
#   2147,
#   3767,
#   4717,
#   607,
#   1542,
#   2159,
#   700,
#   3767,
#   1320,
#   3116,
#   3370,
#   4060,
#   58,
#   4791,
#   3757,
#   4589,
#   4526,
#   2837,
#   3995,
#   504,
#   2314,
#   3137,
#   4424,
#   4005,
#   197,
#   1401,
#   2538,
#   4282,
#   2710,
#   778,
#   3377,
#   1839,
#   4695,
#   3234,
#   4254,
#   4389,
#   565,
#   361,
#   2867,
#   4287,
#   607,
#   1542,
#   313,
#   2039,
#   4282,
#   3671,
#   4804,
#   3688,
#   2956,
#   1686,
#   4211,
#   4490,
#   3757,
#   709,
#   4424,
#   4287,
#   3508,
#   106,
#   3794,
#   1869,
#   197,
#   3018,
#   3556,
#   2845,
#   3370],
#  [4022,
#   403,
#   4804,
#   4931,
#   616,
#   29,
#   316,
#   4804,
#   2845,
#   19,
#   4424,
#   4287,
#   29,
#   4931,
#   2355,
#   4804,
#   1382,
#   4516,
#   1434,
#   4673,
#   1179,
#   813,
#   1645,
#   619,
#   2331,
#   2084,
#   4931,
#   734,
#   1584,
#   1385,
#   4667,
#   3666,
#   3751,
#   189,
#   4667,
#   3785,
#   2992,
#   3767,
#   2406,
#   1298,
#   3041,
#   2592,
#   3750,
#   2986,
#   1434,
#   3507,
#   808,
#   4989,
#   3619,
#   3767,
#   3785,
#   2131,
#   2465,
#   1484,
#   3290,
#   2563,
#   3922,
#   228,
#   2782,
#   3507,
#   4921,
#   4030,
#   1557,
#   3577,
#   565,
#   4331,
#   1579,
#   3619,
#   4347,
#   2986,
#   3941,
#   3070,
#   3895,
#   4103,
#   4538,
#   4236,
#   4203,
#   4960,
#   2924,
#   3145,
#   1043,
#   565,
#   4536,
#   4787,
#   4192,
#   1821,
#   3217,
#   3767,
#   3041,
#   4038,
#   3915,
#   3041,
#   29,
#   1145,
#   4022,
#   4211,
#   1298,
#   2226,
#   2671,
#   4373,
#   2011,
#   4166,
#   4673,
#   1320,
#   515,
#   3596,
#   3596,
#   3657,
#   3326,
#   952,
#   443,
#   1867,
#   3683,
#   2461,
#   46,
#   4804,
#   4787,
#   1429,
#   4804,
#   4804],
#  [3942,
#   4804,
#   2391,
#   1145,
#   883,
#   4989,
#   4929,
#   19,
#   3472,
#   431,
#   4287,
#   4282,
#   3769,
#   977,
#   686,
#   2391,
#   1145,
#   3898,
#   4312,
#   4192,
#   1102,
#   58,
#   4287,
#   4687,
#   2538,
#   887,
#   58,
#   4012,
#   316,
#   4804,
#   633,
#   633,
#   2533,
#   2147,
#   1550,
#   390,
#   4960,
#   700,
#   4621,
#   4424,
#   1550,
#   3902,
#   4804,
#   3995,
#   3116,
#   3898,
#   4630,
#   1407,
#   630,
#   4599,
#   4409,
#   2299,
#   349,
#   3472,
#   1557,
#   227,
#   565,
#   4287,
#   2641,
#   4145,
#   958,
#   2391,
#   1145,
#   883,
#   4536,
#   938,
#   3769,
#   3369],
#  [201,
#   700,
#   4287,
#   2148,
#   2845,
#   431,
#   4804,
#   316,
#   201,
#   3600,
#   3892,
#   4787,
#   4005,
#   1674,
#   986,
#   3137,
#   3389,
#   517,
#   3671,
#   3995,
#   2992,
#   3320,
#   1804,
#   2538,
#   2143],
#  [2200,
#   316,
#   3885,
#   4287,
#   3995,
#   4005,
#   4202,
#   3767,
#   3995,
#   3390,
#   4005,
#   1219,
#   4355,
#   779,
#   293,
#   4355,
#   1219,
#   4516,
#   2845,
#   613,
#   4804,
#   351,
#   3671],
#  [3255,
#   4804,
#   3936,
#   4287,
#   1122,
#   4287,
#   431,
#   2538,
#   3995,
#   4282,
#   120,
#   2314,
#   1488,
#   2566,
#   4027,
#   19,
#   3936,
#   3669,
#   2299,
#   1442,
#   3226,
#   3206],
#  [4287,
#   2402,
#   272,
#   3357,
#   3910,
#   4211,
#   3729,
#   1792,
#   717,
#   4211,
#   4310,
#   2538,
#   3729,
#   3688,
#   2775,
#   1320,
#   3995,
#   4287,
#   4202,
#   2528,
#   1804,
#   3767,
#   3995,
#   4373,
#   1867,
#   3984,
#   3729,
#   3995,
#   4202,
#   1442,
#   2314,
#   2391,
#   1145,
#   1836,
#   1253,
#   1488,
#   4927,
#   4535,
#   2482,
#   2378,
#   1579,
#   4641,
#   4078,
#   4301,
#   2101,
#   4301,
#   3794,
#   1320,
#   3767,
#   3645,
#   3657,
#   3370,
#   688,
#   4192,
#   3661,
#   4620,
#   201,
#   2845,
#   2976,
#   549,
#   1730,
#   4287,
#   3984,
#   3729,
#   4396,
#   1315,
#   1602,
#   2391,
#   1145],
#  [1172,
#   3941,
#   4565,
#   3038,
#   3146,
#   316,
#   4211,
#   2867,
#   3792,
#   2986,
#   4804,
#   3926,
#   892,
#   3700,
#   2986,
#   717,
#   4904,
#   2518,
#   709,
#   4854,
#   3157,
#   3041,
#   4215,
#   3230,
#   251,
#   4143,
#   415,
#   288,
#   686,
#   2148,
#   2420,
#   2815,
#   1686,
#   3767,
#   1172,
#   1142,
#   3282,
#   4956,
#   4192,
#   1540,
#   4984,
#   3700,
#   9,
#   2801,
#   4120,
#   1686,
#   616,
#   4531,
#   688,
#   3280,
#   3767,
#   1787,
#   3041,
#   4984,
#   4693,
#   4630,
#   3700,
#   2825,
#   2847,
#   4897,
#   3364,
#   502,
#   2825,
#   4192,
#   1540,
#   3104,
#   3157,
#   633,
#   4839,
#   2986,
#   4192,
#   918,
#   2233,
#   3926,
#   2692,
#   1583,
#   3146,
#   231,
#   1145,
#   2845,
#   19,
#   4565,
#   4118],
#  [4804,
#   2857,
#   4762,
#   4839,
#   3680,
#   4189,
#   1583,
#   1489,
#   1754,
#   2613,
#   907,
#   4211,
#   2378,
#   4827,
#   4209,
#   2306,
#   1794,
#   4038,
#   2984,
#   4338,
#   3588,
#   4253,
#   1076,
#   2378,
#   3377,
#   4865,
#   3645,
#   2992,
#   818,
#   4793,
#   1378,
#   3767,
#   1320,
#   3645,
#   517,
#   4685,
#   3341,
#   1154,
#   3645,
#   4791,
#   1905,
#   2483,
#   2159,
#   1489,
#   1754,
#   3160,
#   2760,
#   565,
#   4865,
#   3142,
#   4540,
#   4667,
#   4427,
#   2884,
#   2671,
#   4103,
#   2986,
#   3767,
#   4103,
#   892,
#   4211,
#   2680,
#   4331,
#   4166,
#   3926,
#   3657,
#   4536,
#   4787,
#   892,
#   619,
#   3184,
#   2503,
#   135,
#   3941,
#   958,
#   2884,
#   1256,
#   1687,
#   4427,
#   1907,
#   3966,
#   4287,
#   3198,
#   1022,
#   4211,
#   607,
#   1542,
#   2845,
#   4804,
#   217,
#   4192,
#   1821,
#   1930,
#   1919],
#  [4565,
#   4287,
#   3508,
#   1378,
#   3600,
#   1089,
#   3508,
#   1378,
#   3688,
#   2287,
#   2976,
#   942,
#   2538,
#   3048,
#   2011,
#   272,
#   2256,
#   607,
#   1542,
#   546,
#   776,
#   3995,
#   4817,
#   4078,
#   2616,
#   3860,
#   2984,
#   855,
#   1102,
#   743,
#   633,
#   3767,
#   2984,
#   4258,
#   802,
#   802,
#   1692,
#   619,
#   3909,
#   4555,
#   1378,
#   1872,
#   1150,
#   446,
#   4822,
#   803,
#   4737,
#   3439,
#   3280,
#   3909,
#   2103,
#   3688,
#   1347,
#   3942,
#   2420,
#   4398,
#   2671,
#   2420,
#   633,
#   1821,
#   619,
#   2006,
#   633,
#   3280,
#   3069,
#   619,
#   3729,
#   667,
#   4572,
#   1401,
#   3404,
#   58,
#   4536,
#   3332,
#   2420,
#   3281,
#   3332,
#   415,
#   2299,
#   306,
#   3729,
#   688,
#   311,
#   1401,
#   2226,
#   4032,
#   1378,
#   2425,
#   942,
#   1905,
#   4841,
#   3668,
#   565,
#   4801,
#   550,
#   323,
#   3673,
#   2163,
#   2976,
#   3113,
#   790,
#   3741,
#   3370,
#   3548,
#   3937,
#   790,
#   4516,
#   4865,
#   1556,
#   485,
#   2333,
#   3009,
#   674,
#   3767,
#   3995,
#   713,
#   515,
#   192,
#   616,
#   3660,
#   375,
#   3092,
#   644,
#   977,
#   4091,
#   2709,
#   633,
#   737,
#   1819,
#   633,
#   737,
#   3269,
#   4199,
#   1148,
#   1326,
#   3641,
#   1804,
#   734,
#   3473,
#   4436,
#   585,
#   3610,
#   4865,
#   1556,
#   415,
#   485,
#   3178,
#   1930,
#   4322,
#   316,
#   2841,
#   4032,
#   1394,
#   565,
#   4386,
#   3645,
#   3671,
#   1686,
#   2563,
#   2378,
#   4787,
#   4804,
#   977,
#   1831,
#   2372,
#   4121,
#   4386,
#   4532,
#   4165,
#   3309,
#   1930,
#   4322,
#   753,
#   4104,
#   3430,
#   822,
#   4032,
#   3729,
#   4989,
#   3941,
#   3282,
#   4504,
#   4287,
#   4436,
#   3426,
#   3426,
#   3707,
#   1890,
#   1645,
#   619,
#   3168,
#   2314,
#   4192,
#   2845,
#   1398,
#   1603,
#   4637,
#   3645,
#   3657,
#   517,
#   1508,
#   4848,
#   1347,
#   3051,
#   1686,
#   442,
#   3941,
#   442,
#   4804,
#   2315,
#   4883,
#   353,
#   1769,
#   2370,
#   1590,
#   4668,
#   2299,
#   1337,
#   4724,
#   2088,
#   4883,
#   353,
#   4565,
#   1692,
#   1084,
#   3767,
#   1821,
#   2769,
#   565,
#   1629,
#   2867,
#   958,
#   2406,
#   2178,
#   4929,
#   1821,
#   2149,
#   3767,
#   1692,
#   2160],
#  [2538,
#   4287,
#   1073,
#   3767,
#   3887,
#   2159,
#   3290,
#   2314,
#   4287,
#   2143,
#   4531,
#   3327,
#   3602,
#   633,
#   1645,
#   619,
#   2314,
#   4436,
#   1488,
#   250,
#   590,
#   4917,
#   2049,
#   2821,
#   4331,
#   4670,
#   4804,
#   1091,
#   29],
#  [3041,
#   2912,
#   2171,
#   1361,
#   1839,
#   3920,
#   3669,
#   2340,
#   4787,
#   1999,
#   590,
#   2384,
#   977,
#   3301,
#   3941,
#   4287,
#   4539,
#   1473,
#   1934,
#   4287,
#   3440,
#   1550,
#   883,
#   3196,
#   239,
#   3377,
#   2371,
#   3767,
#   197,
#   1401,
#   1484,
#   2956,
#   201,
#   3645,
#   700,
#   3767,
#   1867,
#   4787,
#   3669,
#   3657,
#   1479,
#   272,
#   3902,
#   3017,
#   4287,
#   1583,
#   3767,
#   3370,
#   2639,
#   4641,
#   217,
#   3729,
#   2362,
#   4865,
#   4037,
#   3767,
#   3060,
#   4287,
#   1356,
#   288,
#   2340,
#   2231,
#   1821,
#   1869,
#   1821,
#   3688,
#   2538,
#   2956,
#   1102,
#   1686,
#   2292,
#   3674,
#   565,
#   3569,
#   201,
#   424,
#   1102,
#   4282,
#   69,
#   1730,
#   201,
#   424,
#   155,
#   288,
#   1102,
#   3273,
#   3569,
#   201,
#   424,
#   1668,
#   633,
#   272,
#   4287,
#   3902,
#   4804],
#  [4865,
#   1402,
#   4804,
#   1336,
#   2846,
#   1072,
#   3723,
#   302,
#   4589,
#   3941,
#   4480,
#   4725,
#   3942,
#   4533,
#   688,
#   3562,
#   3767,
#   3941,
#   4331,
#   3619,
#   2733,
#   1686,
#   3648,
#   3941,
#   1821,
#   3276,
#   1336,
#   3760,
#   483,
#   30,
#   3941,
#   819,
#   2845,
#   2923,
#   3041,
#   4659,
#   2472,
#   2763,
#   3505,
#   1821,
#   3276,
#   2272,
#   1320,
#   1219,
#   3280,
#   3648,
#   4211,
#   2733,
#   3623,
#   1821,
#   1488,
#   3512,
#   58,
#   4630,
#   2324,
#   201,
#   4667,
#   4331,
#   1867,
#   2148,
#   4540,
#   485,
#   4211,
#   892,
#   2406,
#   633,
#   4436,
#   4211,
#   2052,
#   1821,
#   3280,
#   3767,
#   46,
#   1787,
#   239,
#   686,
#   539,
#   1336,
#   4839,
#   3942,
#   1102,
#   515,
#   3767,
#   3995,
#   3671,
#   1377,
#   3700,
#   3767,
#   3995,
#   156,
#   4839,
#   4436,
#   1556,
#   3399,
#   3767,
#   4201,
#   4166,
#   3883,
#   811,
#   554,
#   4419,
#   2378,
#   892,
#   4641,
#   1804,
#   4679,
#   3995,
#   4312,
#   4400,
#   192,
#   4490,
#   36,
#   1215,
#   4630,
#   1821,
#   1901,
#   4396,
#   4620,
#   2927,
#   2451,
#   1930,
#   3995,
#   1315,
#   2845,
#   19,
#   4118,
#   4804,
#   2857,
#   3902,
#   2241,
#   3648,
#   4282,
#   4087,
#   4436,
#   696],
#  [376,
#   4287,
#   4691,
#   3635,
#   3133,
#   4516,
#   752,
#   3377,
#   3792,
#   2378,
#   4641,
#   1076,
#   4883,
#   316,
#   3989,
#   3657,
#   3792,
#   2159,
#   3767,
#   3688,
#   2956,
#   197,
#   4282,
#   565,
#   4667,
#   4287,
#   4715,
#   2312,
#   3767,
#   1298,
#   1465,
#   2731,
#   3280,
#   3898,
#   3941,
#   616,
#   316],
#  [1122,
#   2208,
#   4804,
#   4589,
#   398,
#   4287,
#   316,
#   4287,
#   2551,
#   1821,
#   1686,
#   4654,
#   3377,
#   4331,
#   4625,
#   3619,
#   1645,
#   619,
#   2331,
#   443,
#   4192,
#   3661,
#   4942,
#   3280,
#   3619,
#   688,
#   619,
#   1886,
#   2378,
#   1488,
#   4381,
#   3600,
#   140,
#   4865,
#   3767,
#   688,
#   3767,
#   3231,
#   3769,
#   1686,
#   1821,
#   2956,
#   3767,
#   4791,
#   3370,
#   3745,
#   4287,
#   1686,
#   1556,
#   156,
#   3377,
#   2388,
#   3767,
#   3569,
#   3767,
#   2544,
#   4839,
#   3729,
#   1142,
#   4941,
#   1905,
#   4422,
#   1390,
#   897,
#   3016,
#   1024,
#   3139,
#   4211,
#   4589,
#   3645,
#   3231,
#   4417,
#   2580,
#   1631,
#   2695,
#   785,
#   688,
#   1219,
#   3767,
#   4536,
#   1401,
#   4166,
#   4215,
#   3792,
#   4211,
#   1645,
#   619,
#   4984,
#   87,
#   485,
#   398,
#   4802,
#   3767,
#   3915,
#   443,
#   316,
#   4804,
#   4536,
#   4839,
#   19,
#   4287,
#   4118,
#   4589,
#   398,
#   4287,
#   58,
#   2340,
#   3657,
#   4641,
#   1804],
#  [1610,
#   4287,
#   3673,
#   2149,
#   3145,
#   4042,
#   2355,
#   485,
#   2149,
#   4421,
#   4108,
#   449,
#   4211,
#   2639,
#   2986,
#   4472,
#   2149,
#   2111,
#   4421,
#   3767,
#   4421,
#   2149,
#   3505,
#   1849,
#   2111,
#   4216,
#   4078,
#   3767,
#   2149,
#   1821,
#   2976,
#   4042,
#   4282,
#   2149,
#   1390,
#   743,
#   4620,
#   4568,
#   1821,
#   3688,
#   4282,
#   1934,
#   3995,
#   4436,
#   1821,
#   4347,
#   3910,
#   3623,
#   4211,
#   1230,
#   1610,
#   220,
#   2043,
#   3132,
#   437,
#   2043,
#   3132],
#  [958,
#   2483,
#   69,
#   4606,
#   316,
#   3370,
#   4287,
#   2483,
#   4804,
#   616,
#   316,
#   1215,
#   3987,
#   2976,
#   4287,
#   2314,
#   2863,
#   554,
#   3302,
#   2863,
#   3995,
#   1563,
#   3914,
#   1219,
#   3280,
#   3909,
#   3723,
#   3767,
#   1919,
#   2101,
#   3596,
#   2847,
#   4192,
#   2639,
#   4287,
#   4436,
#   2956,
#   1228,
#   1603,
#   3729,
#   1720,
#   3671,
#   2533,
#   3786,
#   3729,
#   3729,
#   565,
#   1603,
#   274,
#   1906,
#   3729,
#   2797,
#   2461,
#   2315,
#   3794,
#   3438,
#   3377,
#   3723,
#   1869,
#   4602,
#   3619,
#   2230,
#   892,
#   4410,
#   4410,
#   892,
#   1230,
#   1869],
#  [2139,
#   4972,
#   4287,
#   2039,
#   2956,
#   4787,
#   4667,
#   2819,
#   4804,
#   3984,
#   3778,
#   4287,
#   796,
#   3767,
#   19,
#   938,
#   1595,
#   120,
#   4027,
#   3729,
#   4282,
#   367,
#   4865,
#   250,
#   1550,
#   120,
#   633,
#   2151,
#   1710,
#   1804,
#   3767,
#   4731,
#   3645,
#   1493,
#   4742,
#   1398,
#   422,
#   3690,
#   2256,
#   4664,
#   4215,
#   1631,
#   3767,
#   907,
#   2992,
#   135,
#   3729,
#   2225,
#   3600,
#   201,
#   4878,
#   4434,
#   1429,
#   958,
#   217,
#   4929,
#   554,
#   4673,
#   4838,
#   3645,
#   3671,
#   2384,
#   3357,
#   1906,
#   4287],
#  [4287,
#   501,
#   316,
#   3145,
#   4424,
#   2483,
#   2442,
#   1412,
#   343,
#   4679,
#   390,
#   546,
#   2538,
#   2584,
#   2538,
#   1642,
#   322,
#   3173,
#   201,
#   424,
#   4282,
#   565,
#   316,
#   1320,
#   2602,
#   3767,
#   3648,
#   3995,
#   3682,
#   2418,
#   3874,
#   3370,
#   4532,
#   4078,
#   1314,
#   3281,
#   4385,
#   1355,
#   1446,
#   2751,
#   3018,
#   431,
#   1730,
#   4532,
#   3122,
#   778,
#   1228,
#   4956,
#   4641,
#   715,
#   199,
#   448,
#   3941,
#   4027,
#   19,
#   4287,
#   1102,
#   1730,
#   3986,
#   559,
#   376,
#   3892,
#   2602],
#  [4287,
#   2538,
#   4589,
#   3275,
#   2538,
#   316,
#   3883,
#   3767,
#   1557,
#   1347,
#   1552,
#   3767,
#   3995,
#   4589,
#   1839,
#   1668,
#   630,
#   4287,
#   4804],
#  [2420,
#   4804,
#   3440,
#   1550,
#   3941,
#   3226,
#   4804,
#   3226,
#   2592,
#   2592,
#   3941,
#   4218,
#   3226,
#   524,
#   3786,
#   4012,
#   4141,
#   590,
#   4804,
#   4787,
#   4531,
#   1434,
#   554,
#   778,
#   4203,
#   4827,
#   3150,
#   3041,
#   3596,
#   4000,
#   1434,
#   3588,
#   4005,
#   2048,
#   590,
#   431,
#   4203,
#   3070,
#   4022,
#   4436,
#   3402,
#   861,
#   316,
#   4203,
#   2845,
#   4417,
#   2845,
#   4417,
#   2048,
#   1769,
#   4282,
#   3671,
#   4804],
#  [2504,
#   4804,
#   1645,
#   3321,
#   4287,
#   316,
#   2314,
#   2992,
#   1488,
#   3941,
#   892,
#   861,
#   1517,
#   4287,
#   3645,
#   4032,
#   2201,
#   3657,
#   517,
#   4287,
#   565,
#   428,
#   1964,
#   3370,
#   861,
#   4641,
#   1867,
#   4787,
#   2847,
#   3454,
#   811,
#   3794,
#   3995,
#   2516,
#   4287,
#   3267,
#   4287,
#   4804,
#   4536,
#   4606,
#   316],
#  [4022,
#   4804,
#   1645,
#   3321,
#   4287,
#   3910,
#   4787,
#   1810,
#   3748,
#   3761,
#   403,
#   18,
#   1810,
#   4804,
#   4762,
#   463,
#   4287,
#   4192,
#   1730,
#   463,
#   1930,
#   3060,
#   316,
#   1122,
#   3377,
#   2976,
#   4282,
#   1730,
#   892,
#   4210,
#   1810,
#   4724,
#   1550,
#   1645,
#   3321,
#   4296,
#   3619,
#   201,
#   3065,
#   4264,
#   2283,
#   1805,
#   1320,
#   3619,
#   201,
#   1215,
#   4282,
#   565,
#   4104,
#   3374,
#   3767,
#   822,
#   3887,
#   4032,
#   3339,
#   1550,
#   791,
#   2131,
#   4762,
#   977,
#   3540,
#   977,
#   3186,
#   3767,
#   977,
#   2533,
#   3657,
#   822,
#   517,
#   3729,
#   3370,
#   2178,
#   2845,
#   1869,
#   1779,
#   3729,
#   1550,
#   4296,
#   2845,
#   1919,
#   1919,
#   2314,
#   2865,
#   4022,
#   4282,
#   3941,
#   403,
#   2476,
#   250,
#   1320,
#   3914,
#   4382,
#   3920,
#   1488,
#   4022,
#   403,
#   2760,
#   2147,
#   3767,
#   565,
#   2613,
#   120,
#   3390,
#   3995,
#   3885,
#   1077,
#   4296,
#   3413,
#   92,
#   4900,
#   2420,
#   2760,
#   3280,
#   4787,
#   2233,
#   942,
#   745,
#   2147,
#   3767,
#   2314,
#   2865,
#   2178,
#   2444,
#   2378,
#   4900,
#   4895,
#   3280,
#   1286,
#   2231,
#   4431,
#   92,
#   1730,
#   4177,
#   328,
#   1686,
#   2449,
#   1645,
#   3321,
#   303,
#   4287,
#   2345,
#   303,
#   2219,
#   2314,
#   2865,
#   1668,
#   2345,
#   4287,
#   4177,
#   2613,
#   4022,
#   316,
#   4145,
#   3984,
#   4804,
#   1645,
#   3321],
#  [459,
#   4373,
#   2518,
#   4436,
#   1556,
#   1320,
#   4373,
#   3301,
#   633,
#   29,
#   4804,
#   1298,
#   4839,
#   3226,
#   918,
#   3357,
#   2518,
#   1847,
#   3499,
#   502,
#   934,
#   3615,
#   4929,
#   192,
#   4211,
#   3941,
#   4417,
#   4532,
#   3280,
#   2858,
#   796,
#   3767,
#   4264,
#   1821,
#   791,
#   3767,
#   2315,
#   3523,
#   4287,
#   4865,
#   1122,
#   192,
#   796,
#   326,
#   2602,
#   1919,
#   791,
#   3767,
#   2315,
#   1919,
#   4762,
#   29,
#   1219,
#   4606,
#   2606,
#   3468,
#   4667,
#   1862,
#   3357,
#   3767,
#   4192,
#   2505,
#   3342,
#   3018,
#   226,
#   3796,
#   3623,
#   4211,
#   4929,
#   2976,
#   2845,
#   4806,
#   4373,
#   3357,
#   1216,
#   4606,
#   4690,
#   1579,
#   1317,
#   1668,
#   4287,
#   3370,
#   3370,
#   2538,
#   554,
#   4804,
#   4995,
#   4540],
#  [4424,
#   517,
#   3333,
#   2476,
#   431,
#   1221,
#   986,
#   4742,
#   181,
#   316,
#   4287,
#   3767,
#   2022,
#   4032,
#   4685,
#   3902,
#   2039,
#   2616,
#   3956,
#   4287,
#   428,
#   2845,
#   2846,
#   4166,
#   887,
#   986,
#   4787,
#   3041,
#   2389,
#   3767,
#   4083,
#   2340,
#   2866,
#   95,
#   3192,
#   3041,
#   1436,
#   1668,
#   1730,
#   181,
#   1598,
#   4145,
#   1219,
#   3280,
#   4536,
#   3941,
#   316],
#  [3255,
#   4804,
#   4565,
#   4287,
#   316,
#   3021,
#   616,
#   969,
#   931,
#   4487,
#   2538,
#   2986,
#   2986,
#   1093,
#   1866,
#   1003,
#   2638,
#   3757,
#   4994,
#   4215,
#   4459,
#   800,
#   2986,
#   3377,
#   3519,
#   1628,
#   3466,
#   2769,
#   244,
#   918,
#   2986,
#   3767,
#   719,
#   2986,
#   2147,
#   4421,
#   4331,
#   3619,
#   3645,
#   234,
#   3767,
#   4793,
#   3669,
#   3993,
#   1645,
#   619,
#   403,
#   4804,
#   515,
#   3767,
#   3995,
#   4373,
#   4166,
#   2011,
#   3390,
#   4654,
#   4215,
#   4104,
#   4355,
#   2530,
#   515,
#   4149,
#   4793,
#   2037,
#   2800,
#   4192,
#   753,
#   4104,
#   4202,
#   1040,
#   1751,
#   3926,
#   3657,
#   3767,
#   3887,
#   4891,
#   1142,
#   415,
#   2293,
#   4536,
#   3004,
#   4984,
#   1102,
#   3750,
#   3767,
#   87,
#   1645,
#   619,
#   191,
#   3505,
#   2639,
#   2847,
#   58,
#   861,
#   403,
#   892,
#   1686,
#   323,
#   4287,
#   2251,
#   4804,
#   316,
#   554,
#   4919,
#   3941,
#   3357,
#   4565],
#  [124,
#   1951,
#   3320,
#   1658,
#   3204,
#   4752,
#   2692,
#   4282,
#   2149,
#   3941,
#   3505,
#   3757,
#   58,
#   4287,
#   2420,
#   1336,
#   2544,
#   4625,
#   4386,
#   4742,
#   1347,
#   3798,
#   1951,
#   2592,
#   1390,
#   4417,
#   4287,
#   4192,
#   2451,
#   938,
#   3184,
#   3122,
#   1484,
#   4192,
#   4518,
#   3611,
#   1651,
#   4762,
#   1283,
#   998,
#   4104,
#   1101,
#   3016,
#   3656,
#   3224,
#   2986,
#   1283,
#   1645,
#   619,
#   3611,
#   502,
#   196,
#   2916,
#   4367,
#   1283,
#   4175,
#   4316,
#   4742,
#   4022,
#   4762,
#   590,
#   4917,
#   2041,
#   2526,
#   3600,
#   2685,
#   714,
#   2256,
#   3615,
#   3792,
#   4436,
#   4287,
#   1429,
#   979,
#   4287,
#   293,
#   4574,
#   3995,
#   4495,
#   3852,
#   3793,
#   2960,
#   3436,
#   699,
#   1283,
#   4625,
#   1595,
#   3792,
#   2986,
#   4531,
#   3671,
#   4904,
#   2518,
#   2231,
#   3143,
#   2845,
#   4540,
#   2019,
#   3661,
#   4022,
#   2545,
#   250,
#   590,
#   4917,
#   4654,
#   3102,
#   4637,
#   3985,
#   316,
#   4689,
#   4166,
#   3669,
#   239,
#   892,
#   1640,
#   3982,
#   2518,
#   2916,
#   2518,
#   2505,
#   2916,
#   3814,
#   3623,
#   3661,
#   4376,
#   312,
#   619,
#   2331,
#   4382,
#   709,
#   2605,
#   2518,
#   323,
#   4742,
#   3436,
#   303,
#   3661,
#   3364,
#   2605,
#   709,
#   2789,
#   2518,
#   250,
#   590,
#   4917,
#   4192,
#   227,
#   4082,
#   3781,
#   4331,
#   3377,
#   4215,
#   3256,
#   1821,
#   1105,
#   4386,
#   1906,
#   1349,
#   958,
#   3002,
#   44,
#   2605,
#   709,
#   4700,
#   4459,
#   554,
#   155,
#   4264,
#   303,
#   3661,
#   892,
#   1451,
#   3700,
#   1356,
#   2465,
#   3926,
#   1525,
#   4700,
#   1922,
#   3861,
#   2503,
#   4287,
#   2251,
#   687,
#   3792,
#   2518,
#   3808,
#   4367,
#   709,
#   2320,
#   4700,
#   3908,
#   2555,
#   688,
#   217,
#   918,
#   442,
#   4787,
#   3032,
#   1338,
#   3353,
#   1914,
#   2692,
#   1451,
#   4093,
#   4166,
#   1548,
#   4166,
#   3947,
#   3910,
#   4762,
#   4787,
#   1810,
#   3623,
#   4211,
#   1951,
#   4904,
#   2518,
#   664,
#   629,
#   3661,
#   693,
#   3505,
#   3319,
#   1003,
#   3414,
#   3286,
#   2834,
#   1219,
#   3132,
#   2782,
#   1429,
#   633,
#   699,
#   4963,
#   2951,
#   1219,
#   3280,
#   4942,
#   619,
#   2331,
#   2371,
#   3263,
#   1914,
#   491,
#   335,
#   861,
#   2331,
#   4192,
#   3792,
#   3615,
#   4264,
#   633,
#   707,
#   3671,
#   1429,
#   633,
#   3600,
#   2095,
#   1429,
#   323,
#   3600,
#   521,
#   4773,
#   4215,
#   3256,
#   1821,
#   4827,
#   1442,
#   1429,
#   4762,
#   4787,
#   2956,
#   1050,
#   2845,
#   3902,
#   4211,
#   3280,
#   4419,
#   2314,
#   2141,
#   4427,
#   4510,
#   476,
#   2314,
#   176,
#   3767,
#   3016,
#   3196,
#   2863,
#   4787,
#   30,
#   1951,
#   3926,
#   861,
#   3286,
#   2522,
#   644,
#   4531,
#   4078,
#   1336,
#   4742,
#   3505,
#   1645,
#   3321,
#   2219,
#   3201,
#   3688,
#   4091,
#   2314],
#  [2847,
#   2639,
#   2504,
#   3671,
#   4804,
#   2314,
#   2863,
#   1834,
#   3995,
#   3116,
#   3767,
#   3645,
#   3657,
#   517,
#   3671,
#   1390,
#   1398,
#   3729,
#   4637,
#   4282,
#   3671,
#   4804],
#  [1603,
#   4078,
#   4287,
#   3226,
#   1421,
#   2039,
#   1583,
#   4550,
#   2475,
#   2541,
#   4287,
#   1603,
#   4287,
#   4282,
#   2314,
#   2566,
#   3767,
#   2503,
#   3645,
#   1356,
#   2349,
#   1804,
#   4032,
#   1687,
#   4552,
#   2932,
#   2613,
#   811,
#   1645,
#   619,
#   2476,
#   2315,
#   625,
#   2847,
#   685,
#   1869,
#   4226,
#   2164,
#   4177,
#   2504,
#   4804,
#   1303,
#   2616,
#   316,
#   3060,
#   3211,
#   2043,
#   4287,
#   2225,
#   4282,
#   4536,
#   3941,
#   4597,
#   751,
#   316,
#   717,
#   4804],
#  [448,
#   3750,
#   4253,
#   2483,
#   2538,
#   3995,
#   4312,
#   2602,
#   4287,
#   3767,
#   2345,
#   2008,
#   2444,
#   1398,
#   2159,
#   1412,
#   340,
#   105,
#   2315,
#   3217,
#   3794,
#   3995,
#   3668,
#   2314,
#   1488,
#   504,
#   2483,
#   4157,
#   4550,
#   3767,
#   2845,
#   4145,
#   4804],
#  [418,
#   3135,
#   887,
#   4287,
#   616,
#   316,
#   4022,
#   4804,
#   4724,
#   1550,
#   977,
#   3767,
#   4791,
#   3671,
#   1465,
#   2314,
#   2503,
#   1488,
#   4091,
#   2538,
#   2863,
#   3729,
#   1930,
#   1686,
#   1821,
#   446,
#   3757,
#   155,
#   278,
#   4027,
#   19],
#  [796,
#   3767,
#   2200,
#   316,
#   3231,
#   3729,
#   4051,
#   4472,
#   3729,
#   4192,
#   4264,
#   4690,
#   3038,
#   1869,
#   4211,
#   4312,
#   3995,
#   1930,
#   3984,
#   2171,
#   4424,
#   4287,
#   633,
#   1488,
#   2378,
#   808,
#   1424,
#   278,
#   3941,
#   2314,
#   4355,
#   2845,
#   2976,
#   549,
#   1730,
#   4424,
#   1804,
#   2355],
#  [4063,
#   4287,
#   3767,
#   4717,
#   607,
#   1542,
#   4192,
#   4357,
#   2917,
#   2009,
#   4800,
#   3767,
#   4287,
#   3765,
#   3508,
#   4312,
#   1261,
#   693,
#   3792,
#   2538,
#   4679,
#   4287,
#   796,
#   3231,
#   200,
#   4063,
#   1686],
#  [4839,
#   796,
#   2837,
#   1398,
#   3029,
#   3671,
#   4839,
#   2923,
#   2511,
#   3910,
#   616,
#   316,
#   2225,
#   4177,
#   4282,
#   3941,
#   2483,
#   3767,
#   1532,
#   3436,
#   4476,
#   2131,
#   4032,
#   3339,
#   1412,
#   4791,
#   3184,
#   1804,
#   1215,
#   3767,
#   630,
#   1172,
#   3657,
#   2503,
#   517,
#   4287,
#   2538,
#   887,
#   156,
#   69,
#   4444,
#   3345,
#   4781,
#   563,
#   3147,
#   2483,
#   565,
#   156,
#   2000,
#   3374,
#   3147,
#   3635,
#   2606,
#   3060,
#   942,
#   1686,
#   2283,
#   1877,
#   4192,
#   201,
#   3671,
#   2845,
#   2476,
#   4804,
#   4287,
#   2314,
#   1488,
#   4005,
#   4253,
#   3276,
#   1488,
#   4158,
#   1488,
#   4203,
#   1374,
#   2845,
#   2476,
#   4804,
#   2837,
#   1398,
#   3029,
#   3671,
#   4536,
#   3941,
#   316,
#   811,
#   4865,
#   1402,
#   4536,
#   616],
#  [2314,
#   4021,
#   619,
#   2331,
#   251,
#   633,
#   4580,
#   2315,
#   3596,
#   3786,
#   4762,
#   2114,
#   619,
#   2331,
#   251,
#   931,
#   3941,
#   3596,
#   2114,
#   4787,
#   4316,
#   2378,
#   2526,
#   2315,
#   597,
#   3767,
#   3645,
#   3370,
#   2159,
#   2917,
#   3657,
#   517,
#   4809,
#   4865,
#   1804,
#   1962,
#   666,
#   2462,
#   1998,
#   3786,
#   2986,
#   195,
#   3814,
#   3786,
#   1919,
#   4287,
#   1005,
#   3641,
#   4204,
#   3814,
#   3767,
#   2782,
#   4361,
#   4361,
#   796,
#   3818,
#   4797,
#   1024,
#   3547,
#   2538,
#   1930,
#   156,
#   2917,
#   4625,
#   4199,
#   4254,
#   2760,
#   3671,
#   2143,
#   1668,
#   3309,
#   2616,
#   1919,
#   4287,
#   1154,
#   4490,
#   161],
#  [2986,
#   398,
#   1919,
#   1550,
#   1209,
#   4464,
#   4929,
#   4929,
#   1065,
#   4654,
#   4287,
#   806,
#   3700,
#   2378,
#   234,
#   796,
#   3767,
#   4078,
#   1866,
#   4287,
#   3103,
#   3767,
#   4421,
#   3505,
#   2639,
#   2451,
#   2378,
#   3767,
#   431,
#   2159,
#   2917,
#   2476,
#   2378,
#   472,
#   3018,
#   2522,
#   1062,
#   2619,
#   4436,
#   2420,
#   2528,
#   2505,
#   3830,
#   3866,
#   4465,
#   2639,
#   2378,
#   4641,
#   2956,
#   3700,
#   2378,
#   3910,
#   3941,
#   398,
#   1919,
#   1550,
#   4192,
#   478,
#   822,
#   2451,
#   2378,
#   3139,
#   1866,
#   4464,
#   4104,
#   4464,
#   794,
#   515,
#   3767,
#   3224,
#   2845,
#   431,
#   4804],
#  [4804,
#   4287,
#   4762,
#   664,
#   2041,
#   1353,
#   2256,
#   3226,
#   2256,
#   4531,
#   3829,
#   4606,
#   2538,
#   2613,
#   2538,
#   3569,
#   201,
#   424,
#   4282,
#   437,
#   69,
#   3631,
#   1398,
#   3029,
#   3671,
#   4282,
#   1576,
#   2984,
#   3309,
#   3767,
#   4951,
#   4841,
#   4258,
#   526,
#   2425,
#   3767,
#   1412,
#   751,
#   2299,
#   1772,
#   3729,
#   621,
#   4177,
#   1142,
#   4555,
#   4238,
#   1157,
#   1603,
#   4568,
#   4238,
#   1286,
#   2368,
#   4645,
#   4620,
#   3320,
#   3729,
#   3657,
#   2671,
#   2984,
#   1347,
#   4436,
#   2597,
#   404,
#   4192,
#   1179,
#   2497,
#   4620,
#   686,
#   1930,
#   2597,
#   3512,
#   796,
#   3767,
#   4722,
#   2845,
#   554,
#   4532,
#   1779,
#   3729,
#   2457,
#   4282,
#   2538,
#   1320,
#   2576,
#   3201,
#   918,
#   2306,
#   3132,
#   3132,
#   2100,
#   1022,
#   937,
#   3132,
#   2100,
#   918,
#   2384],
#  [4022,
#   2692,
#   4625,
#   4839,
#   3369,
#   1615,
#   3103,
#   4722,
#   251,
#   4532,
#   796,
#   1919,
#   1439,
#   1692,
#   1199,
#   2553,
#   1390,
#   3767,
#   3657,
#   3645,
#   517,
#   4715,
#   3377,
#   964,
#   1394,
#   1917,
#   466,
#   2314,
#   1836,
#   2992,
#   2178,
#   3150,
#   863,
#   3830,
#   1686,
#   3688,
#   4145,
#   958,
#   1821,
#   4037,
#   3729],
#  [4804,
#   4989,
#   758,
#   1511,
#   3042,
#   554,
#   4804,
#   4042,
#   4282,
#   1839,
#   3260,
#   3956,
#   3767,
#   3688,
#   4699,
#   1836,
#   4042,
#   3231,
#   806,
#   201,
#   424,
#   4844,
#   1972,
#   3217,
#   3794,
#   2315,
#   2503,
#   4668,
#   2295,
#   4287,
#   1972,
#   1261,
#   1999,
#   4839,
#   4212,
#   4211,
#   861,
#   2231,
#   4742,
#   2845,
#   19,
#   4287,
#   4118],
#  [796,
#   4287,
#   1039,
#   4287,
#   4042,
#   4654,
#   4793,
#   4370,
#   3757,
#   4970,
#   796,
#   3767,
#   4839,
#   3767,
#   1583,
#   1122,
#   796,
#   323,
#   3370,
#   4012,
#   4287,
#   4532,
#   2306,
#   4287,
#   4839,
#   2845,
#   958,
#   4287,
#   4536,
#   4787,
#   4724,
#   218,
#   776,
#   4177,
#   2613,
#   4287,
#   1356,
#   4192,
#   2639,
#   3236,
#   3615,
#   4435,
#   2019,
#   4287,
#   2932,
#   4055,
#   2131,
#   2863,
#   4145,
#   3280],
#  [4177,
#   2483,
#   4804,
#   4565,
#   3767,
#   1598,
#   3729,
#   3011,
#   4287,
#   3729,
#   515,
#   3767,
#   1282,
#   3015,
#   2314,
#   2143,
#   4177,
#   4032,
#   2992,
#   3193,
#   1821,
#   3671,
#   30,
#   2592,
#   3910,
#   4606,
#   316,
#   2314,
#   1488,
#   322,
#   4012,
#   3060,
#   3374,
#   2317,
#   607,
#   1542,
#   156,
#   4287,
#   1818,
#   4804,
#   1393,
#   3767,
#   3995,
#   4166,
#   3015,
#   3643,
#   4839,
#   3671,
#   3902,
#   4804,
#   616,
#   316,
#   3624,
#   87,
#   3669,
#   1563,
#   723,
#   3892,
#   4287,
#   3792,
#   4641,
#   2187,
#   517],
#  [3767,
#   796,
#   3767,
#   3700,
#   1821,
#   2147,
#   3657,
#   892,
#   2976,
#   3359,
#   3657,
#   3767,
#   4421,
#   2483,
#   4421,
#   688,
#   3767,
#   4177,
#   1779,
#   4841,
#   3657,
#   3926,
#   2147,
#   3657,
#   217,
#   1779,
#   4841,
#   3657,
#   404,
#   2201,
#   3540,
#   3767,
#   316,
#   3206,
#   4532,
#   3729,
#   4539,
#   2147,
#   3657,
#   3767,
#   1779,
#   4841,
#   3657,
#   1320,
#   2503,
#   1347,
#   1315,
#   838,
#   3092,
#   554,
#   1951,
#   1169,
#   2845,
#   3286,
#   3898,
#   188,
#   2870,
#   4022,
#   4436,
#   485,
#   30,
#   4641,
#   3873,
#   4839,
#   1930,
#   1320,
#   3794,
#   3767,
#   4589,
#   46,
#   4668,
#   2420,
#   4537,
#   1442,
#   1551,
#   2815,
#   2340,
#   1821,
#   3794,
#   3041,
#   3794,
#   3041,
#   633,
#   4787,
#   2366,
#   2845,
#   2230,
#   4177,
#   3914,
#   3767,
#   3995,
#   3767,
#   3995,
#   4537,
#   2327,
#   3004,
#   2845,
#   918,
#   2226,
#   4436,
#   633,
#   1594,
#   2420,
#   1256,
#   3941,
#   2845,
#   1256,
#   2226,
#   233,
#   2845,
#   1320,
#   1219,
#   345,
#   463,
#   3941,
#   4287,
#   3995,
#   4287,
#   2483,
#   554,
#   3227,
#   4667,
#   2908,
#   3767,
#   3700,
#   4287,
#   3902,
#   4804,
#   2924,
#   4078,
#   1919,
#   3902,
#   709,
#   2908,
#   3767,
#   2846,
#   1517,
#   709,
#   2100,
#   3132,
#   4736,
#   1645,
#   3620,
#   3401,
#   3093,
#   4620,
#   4436,
#   2117,
#   1821,
#   699,
#   4264,
#   4211,
#   303,
#   1821,
#   699,
#   4804,
#   3038,
#   4804,
#   4490,
#   367,
#   861,
#   2406,
#   4287,
#   4417,
#   3845,
#   3750,
#   753,
#   4104,
#   2526,
#   1315,
#   2420,
#   2908,
#   3786,
#   1869,
#   4287,
#   4287,
#   2815,
#   4104,
#   700,
#   3377,
#   3060,
#   3321,
#   3029,
#   2652,
#   3029,
#   1874,
#   4312,
#   633,
#   2420,
#   4104,
#   2503,
#   2231,
#   453,
#   815,
#   3390,
#   1455,
#   4201,
#   4287,
#   1039,
#   1223,
#   3147,
#   607,
#   3281,
#   58,
#   4536,
#   2847,
#   762,
#   3767,
#   2159,
#   1489,
#   1754,
#   3767,
#   3830,
#   323,
#   4287,
#   4192,
#   4357,
#   3810,
#   1754,
#   4287,
#   201,
#   424,
#   2139,
#   4211,
#   3508,
#   201,
#   3676,
#   785,
#   1556,
#   1102,
#   431,
#   3596,
#   3671,
#   1686,
#   3267,
#   4200,
#   2317,
#   4331,
#   2760,
#   1867,
#   3941,
#   1746,
#   1347,
#   1821,
#   2956,
#   3767,
#   2956,
#   3657,
#   2956,
#   3995,
#   2956,
#   4312,
#   3253,
#   3188,
#   349,
#   272,
#   1455,
#   397,
#   3357,
#   4804,
#   3134],
#  [2397,
#   4154,
#   1382,
#   3619,
#   633,
#   272,
#   4287,
#   1730,
#   4091,
#   2751,
#   504,
#   1992,
#   3767,
#   3729,
#   1018,
#   3657,
#   272,
#   4839,
#   2695,
#   3902,
#   3302,
#   4287,
#   376,
#   4885,
#   95,
#   632,
#   510,
#   4552,
#   2383,
#   2504,
#   2837,
#   3914,
#   1298],
#  [2863,
#   2538,
#   3048,
#   607,
#   1542,
#   4762,
#   3048,
#   1398,
#   3029,
#   3671,
#   4645,
#   2424,
#   3029,
#   700,
#   4287,
#   2528,
#   4424,
#   2775,
#   3674,
#   3682,
#   3729,
#   4287,
#   2314,
#   2863,
#   2992,
#   2845],
#  [3942,
#   4804,
#   4589,
#   398,
#   4287,
#   316,
#   4929,
#   3280,
#   2932,
#   2613,
#   2482,
#   3995,
#   4654,
#   892,
#   1645,
#   619,
#   2331,
#   2984,
#   2084,
#   2853,
#   1886,
#   4667,
#   3892,
#   3142,
#   2847,
#   3767,
#   4282,
#   2584,
#   613,
#   1390,
#   1686,
#   1142,
#   4804],
#  [433,
#   2356,
#   1730,
#   4804,
#   4287,
#   501,
#   2504,
#   2906,
#   2159,
#   3792,
#   1821,
#   2606,
#   3688,
#   986,
#   4032,
#   958,
#   3767,
#   3995,
#   3767,
#   1412,
#   4032,
#   4817,
#   3688,
#   2504,
#   2516,
#   167,
#   2845,
#   4027,
#   19,
#   4287,
#   501,
#   4897,
#   4804,
#   3146,
#   1821,
#   2606],
#  [4287,
#   4865,
#   4083,
#   2483,
#   3741,
#   1730,
#   3926,
#   4071,
#   201,
#   837,
#   4202,
#   3260,
#   4379,
#   3699,
#   1077,
#   270,
#   4051,
#   1439,
#   2992,
#   2314,
#   21,
#   3792,
#   892,
#   1836,
#   1804,
#   1484,
#   2340,
#   3993,
#   2845,
#   19,
#   4287,
#   4118,
#   4865,
#   1877,
#   4839,
#   3370,
#   4804,
#   4145,
#   2845,
#   4804],
#  [685,
#   4804,
#   4287,
#   806,
#   4804,
#   501,
#   806,
#   796,
#   501,
#   4037,
#   806,
#   1412,
#   1439,
#   2372,
#   59,
#   4700,
#   4175,
#   3370,
#   343,
#   2775,
#   4679,
#   806,
#   3767,
#   1412,
#   3370,
#   3767,
#   1320,
#   4699,
#   1223,
#   4051,
#   2845,
#   19,
#   4287,
#   1556,
#   3729,
#   4917,
#   390,
#   2131,
#   4917,
#   3332,
#   4917,
#   4809,
#   1818,
#   36,
#   2845,
#   3757,
#   1139,
#   692,
#   3767,
#   942,
#   501,
#   699,
#   3370,
#   4918,
#   2639,
#   3610,
#   2690,
#   350,
#   2950,
#   4728,
#   1320,
#   1997,
#   3729,
#   1172,
#   4809,
#   156,
#   766,
#   4809,
#   771,
#   1053,
#   839,
#   1053,
#   4809,
#   1320,
#   3767,
#   3645,
#   4032,
#   2131,
#   3767,
#   4896,
#   120,
#   1082,
#   2549,
#   2845,
#   19,
#   4804,
#   806,
#   4589,
#   398,
#   1827,
#   4287,
#   3671,
#   1439,
#   2372,
#   4417,
#   3370],
#  [4804,
#   4565,
#   4839,
#   3226,
#   1692,
#   2314,
#   2992,
#   3863,
#   1003,
#   4925,
#   1070,
#   4724,
#   1550,
#   939,
#   486,
#   877,
#   4424,
#   2315,
#   4883,
#   353,
#   3364,
#   1759,
#   2299,
#   3041,
#   4133,
#   1356,
#   517,
#   3657,
#   2314,
#   2538,
#   3792,
#   4282,
#   4804,
#   4095,
#   688,
#   2389,
#   2340,
#   2715,
#   58,
#   4536,
#   1401,
#   2315],
#  [3255,
#   4804,
#   4589,
#   398,
#   4287,
#   316,
#   4386,
#   3226,
#   2504,
#   4804,
#   3688,
#   4804,
#   3767,
#   2147,
#   3657,
#   517,
#   3767,
#   2847,
#   2299,
#   4804,
#   3370,
#   2847,
#   1315,
#   2544,
#   2131,
#   1877,
#   4292,
#   2178,
#   3767,
#   4436,
#   3794,
#   3946,
#   1320,
#   1557,
#   633,
#   4839,
#   3936,
#   3499,
#   1598,
#   2449,
#   1668,
#   4282,
#   4804,
#   958,
#   4536,
#   3941,
#   316],
#  [3146,
#   2857,
#   316,
#   4839,
#   2538,
#   3767,
#   3729,
#   2159,
#   2314,
#   431,
#   3992,
#   4287,
#   3048,
#   3065,
#   4038,
#   1542,
#   2367,
#   4793,
#   1298,
#   777,
#   3048,
#   1836,
#   1804,
#   1805],
#  [3942,
#   2857,
#   316,
#   3255,
#   1286,
#   4804,
#   3887,
#   1550,
#   4312,
#   573,
#   3255,
#   1084,
#   2863,
#   4605,
#   3657,
#   517,
#   2159,
#   4282,
#   2483,
#   4377,
#   3729,
#   2420,
#   3347,
#   4422,
#   4762,
#   1548,
#   4839,
#   3767,
#   1877,
#   986,
#   2800,
#   565,
#   4801,
#   2882,
#   942,
#   303,
#   2863,
#   2314,
#   1354,
#   504,
#   550,
#   1086,
#   3588,
#   4032,
#   3466,
#   2845,
#   2483,
#   4804],
#  [2538,
#   2538,
#   2538,
#   4282,
#   3757,
#   2863,
#   4032,
#   707,
#   1390,
#   4417,
#   3436,
#   4287,
#   4377,
#   1160,
#   3147,
#   2629,
#   3858,
#   1230,
#   4461,
#   3948,
#   3767,
#   1930,
#   4841,
#   3645,
#   1930,
#   3657,
#   1603,
#   4422,
#   2801,
#   859,
#   4382,
#   1934,
#   4848,
#   2301,
#   4994,
#   2314,
#   446,
#   431,
#   504,
#   2507,
#   3920,
#   4212,
#   565,
#   4282,
#   1678,
#   1160,
#   384,
#   3048,
#   2606,
#   2639,
#   1821,
#   3600,
#   3892,
#   3980,
#   3652,
#   2606,
#   3374,
#   3147,
#   3065,
#   607,
#   3345,
#   3160,
#   607,
#   2845,
#   4691,
#   2476,
#   796,
#   4287,
#   4262,
#   811,
#   796,
#   4504,
#   288],
#  [4848,
#   1016,
#   1398,
#   707,
#   2736,
#   1172,
#   3688,
#   2956,
#   4287,
#   4804,
#   316,
#   1885,
#   4211,
#   1919,
#   1304,
#   4839,
#   861,
#   3281,
#   201,
#   3688,
#   4897,
#   4804,
#   3505,
#   4211,
#   2315,
#   4039,
#   4264,
#   3147,
#   2026,
#   1304,
#   578,
#   918,
#   3580,
#   4536,
#   3147,
#   776,
#   3757,
#   2716,
#   1326,
#   3641,
#   550,
#   985,
#   550,
#   4287,
#   3668,
#   4490,
#   4301],
#  [2837,
#   4424,
#   4287,
#   3255,
#   892,
#   1886,
#   4804,
#   316,
#   1398,
#   3029,
#   719,
#   3038,
#   4804,
#   1122,
#   3226,
#   4223,
#   4787,
#   403,
#   4550,
#   1398,
#   3029,
#   446,
#   2605,
#   2602,
#   4051,
#   4804,
#   4287,
#   2984,
#   2483,
#   4629,
#   4177,
#   2613,
#   3671,
#   2605,
#   2698,
#   930,
#   886,
#   1386,
#   3910,
#   4839,
#   2665,
#   2449,
#   2984,
#   1552,
#   1315,
#   3769,
#   4536,
#   4839,
#   3390,
#   3885,
#   4901,
#   4036,
#   3767,
#   3995,
#   4211,
#   1602,
#   4436,
#   3977,
#   3390,
#   1315,
#   2845,
#   3584,
#   1315,
#   1602,
#   4804,
#   4335,
#   2605,
#   2984,
#   443,
#   443,
#   4264,
#   4417,
#   644,
#   120],
#  [3936,
#   316,
#   3198,
#   2538,
#   2629,
#   1045,
#   3132,
#   3883,
#   1886,
#   1637,
#   3767,
#   4282,
#   2159,
#   3160,
#   3767,
#   3995,
#   4421,
#   4166,
#   4787,
#   3767,
#   3364,
#   843,
#   688,
#   2516,
#   2312,
#   167,
#   4282,
#   1686,
#   3004,
#   1633,
#   2312,
#   3226,
#   3116,
#   3794,
#   1450,
#   4552,
#   2924,
#   4552,
#   4421,
#   2420,
#   4166,
#   4787,
#   633,
#   3326,
#   2847,
#   2497,
#   3116,
#   227,
#   2530,
#   2299,
#   986,
#   3390,
#   372,
#   272,
#   3902,
#   2800,
#   3320,
#   2324,
#   554,
#   1102,
#   1906,
#   4282,
#   4287,
#   1730,
#   2845,
#   4804],
#  [4804,
#   1209,
#   633,
#   4839,
#   4192,
#   2504,
#   4804,
#   2314,
#   2992,
#   3767,
#   3370,
#   3645,
#   2733,
#   900,
#   693,
#   4960,
#   3767,
#   3995,
#   3979,
#   1930,
#   3230,
#   3103,
#   4568,
#   1661,
#   4282,
#   2314,
#   3256,
#   950,
#   892,
#   3941,
#   1298,
#   4166,
#   1230,
#   1298,
#   709,
#   3767,
#   4282,
#   2538,
#   201,
#   424,
#   4189,
#   2477,
#   2139,
#   4211,
#   4519,
#   4211,
#   58,
#   1105,
#   3147,
#   3979,
#   2384,
#   3720,
#   1230,
#   3671,
#   3892,
#   2845,
#   2483,
#   4804],
#  [796,
#   3767,
#   4762,
#   4929,
#   1065,
#   4287,
#   2837,
#   316,
#   2114,
#   1003,
#   2986,
#   1602,
#   4654,
#   3757,
#   1645,
#   619,
#   2314,
#   2505,
#   2986,
#   3767,
#   4421,
#   3688,
#   2231,
#   3767,
#   2986,
#   4667,
#   4143,
#   1429,
#   4373,
#   1999,
#   2011,
#   4166,
#   2225,
#   4215,
#   2476,
#   3767,
#   1919,
#   3798,
#   2602,
#   643,
#   2255,
#   995,
#   3526,
#   3767,
#   1142,
#   3507,
#   4551,
#   4075,
#   3914,
#   1919,
#   1556,
#   4042,
#   4177,
#   2639,
#   4287,
#   1836,
#   13,
#   3645,
#   4032,
#   1412,
#   3767,
#   4254,
#   2845,
#   1154,
#   3377,
#   2314,
#   550,
#   1283,
#   4102,
#   323,
#   3767,
#   1426,
#   3507,
#   1142,
#   4192,
#   4021,
#   3645,
#   818,
#   4209,
#   2770,
#   4102,
#   1821,
#   1123,
#   4804],
#  [4931,
#   4287,
#   316,
#   1337,
#   4531,
#   2992,
#   199,
#   4654,
#   2177,
#   155,
#   4531,
#   2992,
#   2314,
#   1836,
#   342,
#   593,
#   4331,
#   3184,
#   892,
#   2616,
#   3776,
#   2845,
#   2007,
#   1756,
#   4177,
#   2231,
#   1710,
#   4331,
#   4742,
#   3624,
#   777,
#   1230,
#   2177,
#   1836,
# ...
#   1003,
#   616,
#   4189,
#   4180,
#   2139,
#   4211,
#   4917,
#   2173,
#   4287,
#   1223,
#   3377,
#   4897,
#   4357,
#   2845,
#   4804,
#   4540,
#   4287,
#   449,
#   1867,
#   2208,
#   2082,
#   633,
#   3683,
#   4436,
#   3450,
#   3813,
#   990,
#   4589,
#   3260,
#   350,
#   942,
#   1154,
#   1903,
#   4078,
#   3436,
#   766,
#   2909,
#   1541,
#   327,
#   3750,
#   3688,
#   4051,
#   4841,
#   3767,
#   2147,
#   3657,
#   350,
#   619,
#   428,
#   3909,
#   3729,
#   1390,
#   3671,
#   350,
#   3019,
#   625,
#   1320,
#   2312,
#   4552,
#   3767,
#   36,
#   1219,
#   1154,
#   3135,
#   4287,
#   4787,
#   4675,
#   4994,
#   4804,
#   2684,
#   428,
#   685,
#   3914,
#   1869,
#   1298,
#   3438,
#   4287,
#   3688,
#   4690,
#   4762,
#   3596,
#   685,
#   3749,
#   1900,
#   4436,
#   144,
#   4503,
#   3074,
#   4503,
#   3729,
#   2592,
#   2082,
#   3956,
#   776,
#   883,
#   1651,
#   2773,
#   1821,
#   3438,
#   2315,
#   883,
#   685,
#   4724,
#   3129,
#   4490,
#   2391,
#   2684,
#   428,
#   515,
#   777,
#   3016,
#   3074,
#   4704,
#   4884,
#   459,
#   3723,
#   4690,
#   3016,
#   3364,
#   4762,
#   597,
#   2889,
#   4436,
#   3723,
#   3074,
#   492,
#   3074,
#   1661,
#   4078,
#   590,
#   1315,
#   4436,
#   1930,
#   3842,
#   3926,
#   1813,
#   3074,
#   3505,
#   777,
#   1122,
#   2208,
#   2563,
#   1821,
#   4865,
#   3139,
#   4357,
#   942,
#   2384,
#   4929,
#   3280,
#   2070,
#   2384,
#   777,
#   1658,
#   2684,
#   428,
#   3342,
#   3074,
#   4808,
#   1171,
#   3729,
#   709,
#   903,
#   3074,
#   1053,
#   3600,
#   1101,
#   3941,
#   892,
#   3767,
#   3995,
#   585,
#   3982,
#   2602,
#   1548,
#   1678,
#   3074,
#   3016,
#   1548,
#   1555,
#   4104,
#   2533,
#   2885,
#   2602,
#   3016,
#   3767,
#   3995,
#   507,
#   3941,
#   2885,
#   2602,
#   778,
#   2225,
#   100,
#   459,
#   2231,
#   3767,
#   3995,
#   3302,
#   1215,
#   2956,
#   2995],
#  [4808,
#   3309,
#   4883,
#   316,
#   3741,
#   4865,
#   1804,
#   4282,
#   4287,
#   3670,
#   3133,
#   3645,
#   2178,
#   1412,
#   4177,
#   1307,
#   4158,
#   1154,
#   4865,
#   4042,
#   1645,
#   619,
#   2314,
#   3370,
#   2178,
#   3910,
#   4667,
#   1717,
#   2055,
#   3700,
#   1869,
#   1298,
#   4021,
#   1219,
#   1869,
#   4798,
#   4839,
#   1717,
#   1298,
#   4203,
#   892,
#   2378,
#   688,
#   3671,
#   1499,
#   485,
#   2976,
#   2639,
#   2986,
#   4742,
#   58,
#   239,
#   3942,
#   796,
#   4287,
#   1230,
#   892,
#   3910,
#   4312,
#   4067,
#   2847,
#   3377,
#   931,
#   4487,
#   1901,
#   3670,
#   3987,
#   4287,
#   2538,
#   4348,
#   3767,
#   1836,
#   3413,
#   2187,
#   2613,
#   3729,
#   4804,
#   202,
#   3892,
#   4287,
#   2011,
#   3729,
#   2956,
#   343,
#   2956,
#   565,
#   688,
#   3767,
#   3645,
#   4051,
#   4166,
#   4804,
#   4762,
#   4839,
#   1821,
#   3657,
#   3792,
#   58,
#   2226,
#   1999,
#   3670,
#   1660,
#   2847,
#   3134,
#   1142,
#   296,
#   1999,
#   188,
#   4396,
#   1804,
#   2377,
#   2420,
#   2782,
#   1811,
#   1142,
#   1442,
#   1836,
#   1535,
#   1920,
#   2314,
#   717,
#   2865,
#   3928,
#   4804],
#  [2041,
#   1024,
#   1642,
#   2041,
#   2483,
#   4199,
#   244,
#   4464,
#   1102,
#   1686,
#   4199,
#   244,
#   832,
#   316,
#   4689,
#   4929,
#   1223,
#   590,
#   4917,
#   4119,
#   4787,
#   4787,
#   778,
#   316,
#   4192,
#   1730,
#   3769,
#   4654,
#   1951,
#   4287,
#   2986,
#   4199,
#   832,
#   244,
#   4250,
#   3757,
#   1919,
#   3767,
#   2606,
#   1686,
#   4102,
#   2378,
#   1105,
#   4386,
#   2043,
#   2178,
#   2384,
#   4166,
#   3757,
#   4199,
#   244,
#   1364,
#   3720,
#   3455,
#   796,
#   323,
#   633,
#   2041,
#   1379,
#   4606,
#   2692,
#   3941,
#   1686,
#   2847,
#   2847,
#   3786,
#   3256,
#   201,
#   2041,
#   873,
#   2695,
#   3910,
#   4839,
#   4192,
#   2111,
#   1642,
#   1024],
#  [4282,
#   3671,
#   4282,
#   2159,
#   2917,
#   3160,
#   201,
#   1356,
#   3645,
#   517,
#   3767,
#   2845,
#   2314,
#   4654,
#   3002,
#   892,
#   892,
#   2846,
#   1806,
#   2383,
#   4762,
#   4787,
#   3146,
#   977,
#   4287,
#   2314,
#   3041,
#   4589,
#   918,
#   1930,
#   3977,
#   2482],
#  [4804,
#   4287,
#   4839,
#   3748,
#   4716,
#   3309,
#   1356,
#   3767,
#   1390,
#   4731,
#   3842,
#   1833,
#   2809,
#   2802,
#   2159,
#   2007,
#   766,
#   2008,
#   4436,
#   2315,
#   3794,
#   4436,
#   1813,
#   4287,
#   2602,
#   4787,
#   4690,
#   4787,
#   3946,
#   3794,
#   1102,
#   2420,
#   3794,
#   3377,
#   1189,
#   709,
#   1999,
#   2420,
#   2420,
#   3623,
#   3767,
#   4319,
#   4211,
#   4618,
#   525,
#   3898,
#   4618,
#   4436,
#   4319,
#   4211,
#   709,
#   1581,
#   3898,
#   4287,
#   4804,
#   2602,
#   2315,
#   1744,
#   3596,
#   2019,
#   2847,
#   4287,
#   1121,
#   1261,
#   1686,
#   2117,
#   3972,
#   3519,
#   4722,
#   3040,
#   2420,
#   3995,
#   4287,
#   4262],
#  [554,
#   3302,
#   1172,
#   3995,
#   1804,
#   3320,
#   4027,
#   1919,
#   4287,
#   796,
#   4287,
#   3767,
#   1747,
#   3472,
#   3769,
#   2923,
#   3236,
#   1122,
#   709,
#   3767,
#   2605,
#   2518,
#   2522,
#   1747,
#   4654,
#   3700,
#   1645,
#   619,
#   2314,
#   2769,
#   1680,
#   709,
#   4038,
#   1747,
#   709,
#   3472,
#   4606,
#   1579,
#   3006,
#   1283,
#   4427,
#   2293,
#   3767,
#   4804,
#   466,
#   3941,
#   3767,
#   4427,
#   2293,
#   1747,
#   688,
#   3767,
#   1179,
#   2293,
#   3880,
#   532,
#   619,
#   450,
#   3006,
#   1877,
#   1645,
#   619,
#   4667,
#   3157,
#   1645,
#   619,
#   4667,
#   353,
#   1102,
#   1219,
#   4776,
#   3880,
#   532,
#   36,
#   2845,
#   2591,
#   3444,
#   811,
#   2605,
#   2293,
#   3767,
#   466,
#   3941,
#   3767,
#   4427,
#   2293,
#   554],
#  [4022,
#   4804,
#   3769,
#   4083,
#   2483,
#   1077,
#   1393,
#   13,
#   1625,
#   1821,
#   1869,
#   4975,
#   4827,
#   4312,
#   1230,
#   4501,
#   1338,
#   4022,
#   4436,
#   688,
#   808,
#   144,
#   3507,
#   4977,
#   1421,
#   2845,
#   4145,
#   4804,
#   2845,
#   19,
#   4118,
#   4804,
#   316,
#   3060],
#  [616,
#   348,
#   316,
#   1102,
#   4804,
#   4287,
#   1372,
#   4424,
#   1320,
#   3841,
#   2992,
#   4565,
#   1836,
#   2497,
#   687,
#   1320,
#   1488,
#   2384,
#   3987,
#   1934,
#   863,
#   2117,
#   1686,
#   931,
#   4061,
#   1506,
#   3987,
#   1934,
#   3588,
#   3910,
#   892,
#   3980,
#   2483,
#   863,
#   2986,
#   4994,
#   1637,
#   2420,
#   3904,
#   3941,
#   3979,
#   270,
#   4654,
#   316,
#   1434,
#   1652,
#   1401,
#   3863,
#   2528,
#   1804,
#   1102,
#   1804,
#   1420,
#   1834,
#   4490,
#   616,
#   316,
#   3910,
#   3941,
#   4724,
#   922,
#   2147,
#   2684,
#   2147,
#   2698,
#   3767,
#   1337,
#   4424,
#   3198,
#   1320,
#   958,
#   3645,
#   2138,
#   2381,
#   168,
#   3657,
#   1258,
#   2428,
#   1556,
#   688,
#   1930,
#   4839,
#   355,
#   3657,
#   2671,
#   351,
#   715,
#   1361,
#   2178,
#   1488,
#   745,
#   3280,
#   1320,
#   2420,
#   2715,
#   2497,
#   218,
#   1603,
#   218,
#   323,
#   4282,
#   4312,
#   4565,
#   4621,
#   546,
#   4287,
#   3768,
#   2389,
#   3116,
#   892,
#   3979,
#   1637,
#   1367,
#   4287,
#   1821,
#   3764,
#   19,
#   3782,
#   695,
#   4791,
#   3255,
#   4724,
#   2314,
#   2618,
#   2992,
#   3701,
#   2538,
#   887,
#   2299],
#  [4804,
#   4883,
#   316,
#   4287,
#   3029,
#   4141,
#   4989,
#   590,
#   633,
#   492,
#   4287,
#   1730,
#   3902,
#   3910,
#   3926,
#   892,
#   1680,
#   2729,
#   2314,
#   2084,
#   1836,
#   2956,
#   2847,
#   1488,
#   892,
#   688,
#   3767,
#   861,
#   791,
#   2131,
#   3767,
#   4896,
#   3645,
#   3280,
#   3377,
#   1836,
#   4641,
#   202,
#   2149,
#   251,
#   323,
#   3767,
#   3926,
#   3280,
#   892,
#   2769,
#   3767,
#   4896,
#   1320,
#   3674,
#   2461,
#   3657,
#   3729,
#   573,
#   748,
#   3926,
#   3767,
#   992,
#   2844,
#   3792,
#   3657,
#   3645,
#   2976,
#   921,
#   4536,
#   616,
#   3377,
#   2314,
#   251,
#   4887,
#   1884,
#   323,
#   3767,
#   2503,
#   4202,
#   2482,
#   3995,
#   4767,
#   3767,
#   2528,
#   1804,
#   4804,
#   4839,
#   1132,
#   1315,
#   4839,
#   4883,
#   1091,
#   4804,
#   2606],
#  [2538,
#   1930,
#   892,
#   2402,
#   4667,
#   4427,
#   2293,
#   3767,
#   1919,
#   2131,
#   2011,
#   2293,
#   2011,
#   4427,
#   2293,
#   4192,
#   1142,
#   2293,
#   156,
#   2597,
#   1401,
#   1101,
#   4667,
#   3696,
#   3767,
#   4427,
#   2293,
#   2131,
#   808,
#   1787,
#   1686,
#   3377,
#   1821,
#   3596,
#   4192,
#   190,
#   4335,
#   2184,
#   734,
#   2265,
#   58,
#   1240,
#   469,
#   3767,
#   633,
#   4438,
#   4204,
#   4211,
#   2680,
#   554,
#   443,
#   3767,
#   289,
#   3995,
#   3004,
#   3645,
#   4211,
#   4103,
#   4654,
#   3280,
#   3767,
#   4752,
#   4787,
#   2650,
#   2605,
#   3647,
#   302,
#   485,
#   2845,
#   1219,
#   554,
#   3364,
#   485,
#   2845,
#   4215,
#   3700,
#   1219,
#   3941,
#   1102,
#   1821,
#   3276,
#   1686,
#   1557,
#   554,
#   1434,
#   4118,
#   3364,
#   3926,
#   4804,
#   1441,
#   941,
#   941,
#   796,
#   4804,
#   2845,
#   4804,
#   554,
#   4804,
#   4287,
#   3914,
#   4839],
#  [4804,
#   4490,
#   161,
#   1730,
#   554,
#   3902,
#   1669,
#   1930,
#   861,
#   892,
#   4568,
#   3413,
#   1637,
#   2331,
#   630,
#   3926,
#   3767,
#   4865,
#   3600,
#   1836,
#   2402,
#   3910,
#   3234,
#   2409,
#   3657,
#   3865,
#   4249,
#   3657,
#   4589,
#   603,
#   2143,
#   2391,
#   4787,
#   4793,
#   4252,
#   2019,
#   861,
#   3280,
#   188,
#   4282,
#   2117,
#   4637,
#   1101,
#   4422,
#   2845,
#   1488,
#   3280,
#   3503,
#   4422,
#   2225,
#   4637,
#   1398,
#   1779,
#   1521,
#   237,
#   1603,
#   3362,
#   2605,
#   4487,
#   1154,
#   586,
#   4082,
#   1398,
#   1179,
#   1379,
#   4211,
#   1645,
#   619,
#   1488,
#   2331,
#   1123,
#   1610,
#   699,
#   2225,
#   95,
#   2643,
#   2801,
#   2605,
#   1228,
#   1368,
#   4357,
#   4355,
#   2801,
#   3982,
#   36,
#   605,
#   3133,
#   1368,
#   4865,
#   1804,
#   375,
#   1105,
#   4601,
#   2942,
#   36,
#   918,
#   2233,
#   3926,
#   1645,
#   619,
#   4984,
#   2331,
#   1836,
#   1556,
#   3157,
#   36,
#   2251,
#   4253,
#   1123,
#   1342,
#   2420,
#   3661,
#   2942,
#   616,
#   2602,
#   2315,
#   4839,
#   861,
#   4804,
#   3671,
#   3902],
#  [4931,
#   4287,
#   1337,
#   4424,
#   4417,
#   4287,
#   1154,
#   1730,
#   3295,
#   2956,
#   549,
#   2563,
#   3436,
#   3767,
#   796,
#   3645,
#   3229,
#   3729,
#   4865,
#   415,
#   990,
#   2790,
#   3301,
#   3645,
#   4989,
#   4742,
#   2461,
#   1286,
#   3767,
#   2476,
#   1315,
#   2131,
#   1472,
#   3645,
#   1579,
#   942,
#   3767,
#   293,
#   4427,
#   2293,
#   3767,
#   4192,
#   4417,
#   1035,
#   327,
#   2256,
#   2293,
#   2976,
#   2314,
#   4021,
#   4287,
#   4032,
#   1003,
#   2541,
#   4078,
#   565,
#   4212,
#   69,
#   3569,
#   201,
#   424,
#   4192,
#   1919,
#   4690,
#   3767,
#   1730,
#   3137,
#   3767,
#   2845,
#   4804,
#   4931,
#   4287],
#  [2538,
#   2847,
#   2371,
#   4804,
#   4565,
#   4192,
#   4022,
#   3669,
#   3450,
#   1043,
#   3065,
#   3741,
#   1393,
#   554,
#   442,
#   2751,
#   2039,
#   2576,
#   2680,
#   2314,
#   2426,
#   4848,
#   1070,
#   2956,
#   1550,
#   633,
#   1919,
#   4287,
#   4343,
#   140,
#   4017,
#   1401,
#   918,
#   3281,
#   1867,
#   3645,
#   3767,
#   1219,
#   3767,
#   4625,
#   3941,
#   892,
#   2908,
#   4216,
#   3139,
#   1398,
#   4287,
#   4633,
#   4804,
#   1320,
#   4259,
#   1387,
#   3041,
#   2255,
#   2602,
#   4436,
#   4984,
#   4625,
#   3941,
#   1645,
#   619,
#   2314,
#   1834,
#   3977,
#   293,
#   3370,
#   2692,
#   1215,
#   3357,
#   4804,
#   4641,
#   4673,
#   1583,
#   2149,
#   3767,
#   4634,
#   4817,
#   3729,
#   4436,
#   824,
#   3892,
#   4287,
#   4804,
#   42,
#   288,
#   2956,
#   3146],
#  [4022,
#   3669,
#   316,
#   4177,
#   2143,
#   1804,
#   4789,
#   4287,
#   2314,
#   3661,
#   4022,
#   1320,
#   4804,
#   597,
#   1645,
#   619,
#   2314,
#   3920,
#   1919,
#   4798,
#   330,
#   565,
#   428,
#   330,
#   431,
#   3767,
#   3887,
#   1402,
#   4201,
#   95,
#   4177,
#   4282,
#   1905,
#   3767,
#   586,
#   3668,
#   2340,
#   1356,
#   633,
#   27,
#   4282,
#   2159,
#   1847,
#   2131,
#   607,
#   3345,
#   1668,
#   4282,
#   4804,
#   4027,
#   19],
#  [548,
#   3926,
#   316,
#   3769,
#   403,
#   4804,
#   4287,
#   29,
#   3041,
#   3440,
#   1550,
#   54,
#   688,
#   2255,
#   196,
#   4177,
#   2992,
#   1821,
#   3995,
#   1869,
#   4211,
#   4287,
#   892,
#   1847,
#   2131,
#   565,
#   489,
#   4287,
#   3147,
#   776,
#   1320,
#   3792,
#   3757,
#   4287,
#   4079,
#   1154,
#   3283,
#   4923,
#   2225,
#   4923,
#   58,
#   3092,
#   3147,
#   4203,
#   1645,
#   619,
#   2992,
#   3904,
#   3767,
#   3645,
#   811,
#   4610,
#   4804,
#   4287,
#   3370,
#   3364,
#   808,
#   217,
#   2977,
#   565,
#   3641,
#   4382,
#   3390,
#   2516,
#   3596,
#   4282,
#   586,
#   3390,
#   952,
#   4496,
#   3431,
#   1066,
#   2888,
#   2524,
#   706,
#   2136,
#   2677,
#   4287,
#   201,
#   424,
#   1356,
#   3229,
#   2893,
#   1489,
#   1754,
#   4252,
#   607,
#   3345,
#   1320,
#   2315,
#   1717,
#   1668,
#   2845,
#   982,
#   4804,
#   2845,
#   19,
#   233],
#  [3723,
#   811,
#   1298,
#   3071,
#   4753,
#   2639,
#   3641,
#   3657,
#   4211,
#   619,
#   4667,
#   485,
#   748,
#   4192,
#   1219,
#   46,
#   3657,
#   3942,
#   3770,
#   1102,
#   3657,
#   46,
#   3647,
#   4761,
#   4102,
#   808,
#   3071,
#   4264,
#   2695,
#   1169,
#   1905,
#   2226,
#   323,
#   1905,
#   2226,
#   4753,
#   4192,
#   1919,
#   46,
#   3071,
#   4753,
#   1869,
#   3688,
#   4839,
#   2695,
#   1179,
#   1169,
#   4122,
#   3765,
#   2836,
#   2482],
#  [4287,
#   272,
#   4287,
#   3902,
#   1625,
#   4177,
#   2504,
#   1356,
#   2847,
#   1320,
#   4078,
#   463,
#   4051,
#   1804,
#   4287,
#   4628,
#   3898,
#   1992,
#   3133,
#   861,
#   3767,
#   1356,
#   1836,
#   4409,
#   2865,
#   4254,
#   1669,
#   4791,
#   4641,
#   1680,
#   2131,
#   308,
#   992,
#   633,
#   942,
#   633,
#   4177,
#   2845,
#   1686,
#   633,
#   1804,
#   3184,
#   2845,
#   4357,
#   1540,
#   1215,
#   4791,
#   3745,
#   686,
#   1934,
#   586],
#  [3855,
#   1199,
#   1839,
#   1645,
#   619,
#   3898,
#   3941,
#   4211,
#   2845,
#   433,
#   2483,
#   4215,
#   1839,
#   415,
#   4726,
#   2518,
#   1456,
#   1303,
#   1984,
#   717,
#   155,
#   316,
#   3302,
#   2314,
#   2845,
#   1488,
#   2050,
#   3600,
#   977,
#   829,
#   3060,
#   3226,
#   4177,
#   4865,
#   1402,
#   4883,
#   353,
#   3438,
#   3226,
#   3851,
#   2845,
#   1686,
#   1816,
#   2563,
#   3436,
#   4367,
#   2230,
#   3295,
#   4264,
#   1686,
#   4319,
#   3794,
#   4104,
#   3142,
#   3767,
#   4287,
#   1680,
#   1385,
#   3765,
#   3995,
#   4104,
#   1154,
#   3309],
#  [4022,
#   2692,
#   1810,
#   316,
#   4405,
#   3941,
#   4804,
#   4287,
#   501,
#   2148,
#   2845,
#   3987,
#   1730,
#   4787,
#   633,
#   4568,
#   796,
#   2986,
#   2314,
#   541,
#   4021,
#   1216,
#   3519,
#   3979,
#   1637,
#   1367,
#   4103,
#   4568,
#   892,
#   4787,
#   1810,
#   2482,
#   3995,
#   2314,
#   3792,
#   2378,
#   4641,
#   217,
#   2271,
#   3767,
#   700,
#   3648,
#   3995,
#   2863,
#   250,
#   1919,
#   4762,
#   2269],
#  [4531,
#   4762,
#   1122,
#   3253,
#   316,
#   4804,
#   1122,
#   883,
#   3029,
#   1436,
#   3941,
#   2504,
#   3898,
#   3619,
#   4804,
#   822,
#   4287,
#   1872,
#   4841,
#   3671,
#   3542,
#   1077,
#   2992,
#   4574,
#   274,
#   3092,
#   4791,
#   3168,
#   3436,
#   4287,
#   4396,
#   2847,
#   4192,
#   2504,
#   4917,
#   4254,
#   2326,
#   1803,
#   62,
#   4287,
#   3671,
#   1930,
#   3528,
#   686,
#   432,
#   737,
#   529,
#   3377,
#   1382,
#   2270,
#   4804,
#   2418,
#   4570,
#   4287,
#   4347,
#   4742,
#   693,
#   1421,
#   688,
#   4051,
#   1919,
#   4804,
#   4192,
#   4526,
#   155,
#   938,
#   3671],
#  [4804,
#   2200,
#   4012,
#   316,
#   3688,
#   1513,
#   4804,
#   3688,
#   1730,
#   4287,
#   2538,
#   4282,
#   3060,
#   1821,
#   4319,
#   3142,
#   4287,
#   4078,
#   1598,
#   2845,
#   1928,
#   4762,
#   1171,
#   4212,
#   565,
#   428,
#   986,
#   1821,
#   4282,
#   3390,
#   3767,
#   4841,
#   3657,
#   1479,
#   517,
#   3902,
#   3757,
#   4215,
#   3995,
#   4288,
#   1594,
#   155,
#   4857,
#   2200,
#   4687,
#   1050,
#   1668,
#   2845,
#   4027,
#   19,
#   4287,
#   4118,
#   4865,
#   1513,
#   4287],
#  [4804,
#   4762,
#   4839,
#   883,
#   316,
#   4989,
#   3941,
#   4804,
#   4654,
#   4192,
#   1540,
#   4287,
#   2602,
#   2315,
#   4211,
#   1102,
#   2340,
#   1869,
#   4804,
#   4839,
#   4042,
#   1320,
#   3018,
#   3645,
#   343,
#   3767,
#   3645,
#   1540,
#   343,
#   3645,
#   4540,
#   2671,
#   693,
#   717,
#   4620,
#   4162,
#   1320,
#   192,
#   120,
#   4287,
#   492,
#   3785,
#   1315,
#   323,
#   2256,
#   1425,
#   1804,
#   3645,
#   4287,
#   1230,
#   4162,
#   965,
#   4963,
#   1842,
#   42,
#   288,
#   4804,
#   1804,
#   554,
#   3227,
#   4264,
#   4211,
#   2576,
#   3661,
#   4690,
#   3505,
#   42,
#   288,
#   4262,
#   3914,
#   3357,
#   4317,
#   4839],
#  [4883,
#   431,
#   4287,
#   1052,
#   4811,
#   4177,
#   4793,
#   403,
#   918,
#   3979,
#   1061,
#   167,
#   1102,
#   1821,
#   3657,
#   4083,
#   4814,
#   1102,
#   918,
#   217,
#   3995,
#   4282,
#   4296,
#   633,
#   2371,
#   2371,
#   4287,
#   594,
#   3902,
#   4804,
#   4177,
#   3370,
#   565,
#   3133,
#   2863,
#   3390],
#  [4804,
#   4568,
#   3639,
#   1473,
#   1934,
#   2013,
#   3313,
#   1645,
#   619,
#   2314,
#   383,
#   633,
#   1874,
#   29,
#   2975,
#   892,
#   2426,
#   3767,
#   2602,
#   2775,
#   2131,
#   1847,
#   1079,
#   892,
#   202,
#   1424,
#   965,
#   778,
#   3757,
#   4935,
#   4742,
#   2008,
#   1266,
#   4935,
#   4742,
#   2461,
#   2809,
#   990,
#   4211,
#   3645,
#   3767,
#   3792,
#   2602,
#   600,
#   4724,
#   4436,
#   3139,
#   3074,
#   1645,
#   619,
#   2331,
#   4963,
#   1219,
#   1821,
#   1787,
#   323,
#   3767,
#   1804,
#   3941,
#   3309,
#   1804,
#   703,
#   4287,
#   703,
#   1465,
#   21,
#   2241,
#   990,
#   2606,
#   4312,
#   1821,
#   2315,
#   1751,
#   753,
#   4104],
#  [4376,
#   323,
#   3941,
#   2149,
#   2084,
#   1645,
#   619,
#   1488,
#   630,
#   1862,
#   156,
#   2326,
#   387,
#   3508,
#   1610,
#   4417,
#   4331,
#   2355,
#   3818,
#   892,
#   4654,
#   1836,
#   892,
#   3941,
#   1571,
#   1424,
#   3588,
#   4679,
#   1006,
#   3131,
#   554,
#   4159,
#   3818,
#   4878,
#   3767,
#   4093,
#   4331,
#   3377,
#   3619,
#   1377,
#   4417,
#   4865,
#   3818,
#   2340,
#   2479,
#   3508,
#   220,
#   492,
#   2256,
#   3263,
#   4202,
#   4887,
#   41,
#   3142,
#   1683,
#   1645,
#   619,
#   4630,
#   3765,
#   1862,
#   532,
#   4472,
#   2384,
#   326,
#   2639,
#   1584,
#   502,
#   2251,
#   4804,
#   2101,
#   4531,
#   3364,
#   3377,
#   2456,
#   3004,
#   1320,
#   796,
#   1919,
#   2101,
#   4211,
#   41,
#   861,
#   892,
#   892,
#   687,
#   2238,
#   217,
#   688,
#   2043,
#   3092,
#   4436,
#   4989,
#   1834,
#   1930,
#   1390,
#   1645,
#   619,
#   2528,
#   4067,
#   2767,
#   4887,
#   41,
#   4177,
#   3940,
#   4610,
#   3286,
#   2528,
#   4584,
#   2976,
#   492,
#   2256,
#   3910,
#   4606,
#   316,
#   4287,
#   4032,
#   3339,
#   3377,
#   1390,
#   1964,
#   4282,
#   2538,
#   4032,
#   1583,
#   2314,
#   1836,
#   2992,
#   50,
#   1017,
#   1919,
#   4287,
#   3209,
#   3573,
#   1315,
#   3669,
#   1804,
#   2845,
#   3595,
#   4312,
#   1354,
#   1000,
#   3995,
#   1003,
#   4192,
#   3624,
#   732,
#   2007,
#   3669,
#   1730,
#   2563,
#   3436],
#  ...]

# %% [markdown]
# ### Embedding Representation

# %%
sent_length=20
embedded_docs=pad_sequences(onehot_repr,padding='pre',maxlen=sent_length)
embedded_test = pad_sequences(onehot_test,padding='pre',maxlen=sent_length)
print(embedded_docs)
# Out:
# [[1867 3941 4027 ...  958 1616 1780]
#  [ 412 3955 3767 ...  453 4629  303]
#  [4865 1804   36 ... 1356 4287 2602]
#  ...
#  [1402 2420  156 ... 2956 2692 3134]
#  [3226  316 3767 ...  854 1077 3041]
#  [1024 4039 1258 ...  709   19 4287]]

# %%
embedded_docs[2]
# Out:
# array([4865, 1804,   36, 1042, 4192, 3294,  554, 1686, 4287, 4436, 2772,
#         590, 2371, 4287,  554,   19, 4118, 1356, 4287, 2602], dtype=int32)

# %%
## LSTM: Creating model
embedding_vector_features=40
model=Sequential()
model.add(Embedding(voc_size,embedding_vector_features,input_length=sent_length))
model.add(Dropout(0.3))
model.add(LSTM(100))
model.add(Dropout(0.3))
model.add(Dense(1,activation='sigmoid'))
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=['BinaryAccuracy'])
print(model.summary())
# Out:
# 2022-04-27 10:56:30.081593: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 20, 40)            200000
#
#  dropout (Dropout)           (None, 20, 40)            0
#
#  lstm (LSTM)                 (None, 100)               56400
#
#  dropout_1 (Dropout)         (None, 100)               0
#
#  dense (Dense)               (None, 1)                 101
#
# =================================================================
# Total params: 256,501
# Trainable params: 256,501
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
## Bidirectional LSTM: Creating model
embedding_vector_features=40
model1=Sequential()
model1.add(Embedding(voc_size,embedding_vector_features,input_length=sent_length))
model1.add(Dropout(0.3))
model1.add(Bidirectional(LSTM(100)))
model1.add(Dropout(0.3))
model1.add(Dense(1,activation='sigmoid'))
model1.compile(loss='binary_crossentropy',optimizer='adam',metrics=['BinaryAccuracy'])
print(model1.summary())
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 20, 40)            200000
#
#  dropout_2 (Dropout)         (None, 20, 40)            0
#
#  bidirectional (Bidirectiona  (None, 200)              112800
#  l)
#
#  dropout_3 (Dropout)         (None, 200)               0
#
#  dense_1 (Dense)             (None, 1)                 201
#
# =================================================================
# Total params: 313,001
# Trainable params: 313,001
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
len(embedded_docs),y.shape
# Out:
# (1590, (1590,))

# %%
import numpy as np
X_final=np.array(embedded_docs)
y_final=np.array(y)

x_manual = np.array(embedded_test)
y_manual = np.array(y_manual)

# %%
X_final
# Out:
# array([[1867, 3941, 4027, ...,  958, 1616, 1780],
#        [ 412, 3955, 3767, ...,  453, 4629,  303],
#        [4865, 1804,   36, ..., 1356, 4287, 2602],
#        ...,
#        [1402, 2420,  156, ..., 2956, 2692, 3134],
#        [3226,  316, 3767, ...,  854, 1077, 3041],
#        [1024, 4039, 1258, ...,  709,   19, 4287]], dtype=int32)

# %%
x_manual
# Out:
# array([[1804, 4804, 2497, 2371, 4022,  778, 3255, 4857, 3038, 4804, 4536,
#         4606,  202, 2269,  707, 3671, 1488, 2378, 2504, 4804],
#        [2846, 2695,  633, 3523, 4567,  892,  892, 4700, 4519, 4287,  202,
#         3412, 1581,  554, 4804,  779, 3569, 4490, 1442, 1540],
#        [3438, 4742, 3767, 3437, 1402, 4201, 2381,   84, 3657, 4762, 1160,
#         3523, 4299, 3623,  197, 4287, 3785, 2992, 4145, 4804],
#        [4282, 3437,  481, 2159,  677, 4994, 1603, 1401,  998, 4082, 4994,
#         3767, 3995, 4282, 3004, 2312, 3891, 1668, 2160, 1730],
#        [1402, 4201, 2381,  986, 3290, 1885, 3892, 3741, 4145,  796, 3767,
#         4536, 3941,  316, 4145, 2834, 4804, 3440, 1550, 3892],
#        [4005, 4282, 3767, 3671, 4068, 4347, 4287,  394, 4989,  590, 2538,
#         4417, 1598,  333, 1101, 4282,  565, 3569,  201,  424],
#        [3060, 3645,   92, 4005, 2226,  554, 1836,  707, 3995, 3196,  958,
#         2845,   19, 4804, 3440, 1550,  883,  316, 4012, 4118],
#        [4166, 3466, 3720, 4896, 4793, 2695, 3444, 1159,  998, 4252, 4994,
#         1429,  289,  492, 4804, 2751, 4202, 4762,  590, 4917],
#        [4166,  191,  808, 4853, 4839, 2251, 1797,  688, 1219, 2808, 3767,
#         1281, 3741, 1668, 1730, 4804, 1836, 1550,  796, 3902],
#        [ 990, 3370, 4791, 4865, 3767, 3887, 3645, 4390, 4287, 3060,   19,
#         4287, 4531,   29, 2845,   19, 4118, 1686, 4804, 3060]],
#       dtype=int32)

# %%
X_final.shape,y_final.shape
# Out:
# ((1590, 20), (1590,))

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_final, y_final, test_size=0.33, random_state=52)

# %%
X_train[1]
# Out:
# array([2503, 2976, 4202, 1730,  633, 4839, 2476, 3902, 4804, 4287,  239,
#        1563,  883, 3600, 1692, 3984, 2769,  288,  883,  316], dtype=int32)

# %% [markdown]
# ### Model Training

# %%
### LSTM Training
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=25,batch_size=32, verbose = 2)
# Out:
# Epoch 1/25
# 34/34 - 1s - loss: 0.3166 - binary_accuracy: 0.8883 - val_loss: 0.3582 - val_binary_accuracy: 0.8857 - 625ms/epoch - 18ms/step
# Epoch 2/25
# 34/34 - 1s - loss: 0.1637 - binary_accuracy: 0.9502 - val_loss: 0.3566 - val_binary_accuracy: 0.8743 - 606ms/epoch - 18ms/step
# Epoch 3/25
# 34/34 - 1s - loss: 0.0819 - binary_accuracy: 0.9793 - val_loss: 0.4577 - val_binary_accuracy: 0.8667 - 589ms/epoch - 17ms/step
# Epoch 4/25
# 34/34 - 1s - loss: 0.0338 - binary_accuracy: 0.9906 - val_loss: 0.5123 - val_binary_accuracy: 0.8724 - 577ms/epoch - 17ms/step
# Epoch 5/25
# 34/34 - 1s - loss: 0.0154 - binary_accuracy: 0.9972 - val_loss: 0.7507 - val_binary_accuracy: 0.8514 - 512ms/epoch - 15ms/step
# Epoch 6/25
# 34/34 - 1s - loss: 0.0168 - binary_accuracy: 0.9953 - val_loss: 0.6964 - val_binary_accuracy: 0.8552 - 525ms/epoch - 15ms/step
# Epoch 7/25
# 34/34 - 1s - loss: 0.0096 - binary_accuracy: 0.9981 - val_loss: 0.7239 - val_binary_accuracy: 0.8476 - 510ms/epoch - 15ms/step
# Epoch 8/25
# 34/34 - 1s - loss: 0.0046 - binary_accuracy: 0.9991 - val_loss: 0.8361 - val_binary_accuracy: 0.8419 - 514ms/epoch - 15ms/step
# Epoch 9/25
# 34/34 - 1s - loss: 0.0036 - binary_accuracy: 0.9991 - val_loss: 0.7985 - val_binary_accuracy: 0.8438 - 515ms/epoch - 15ms/step
# Epoch 10/25
# 34/34 - 1s - loss: 0.0047 - binary_accuracy: 0.9991 - val_loss: 0.7132 - val_binary_accuracy: 0.8457 - 508ms/epoch - 15ms/step
# Epoch 11/25
# 34/34 - 1s - loss: 0.0062 - binary_accuracy: 0.9991 - val_loss: 0.8813 - val_binary_accuracy: 0.8514 - 512ms/epoch - 15ms/step
# Epoch 12/25
# 34/34 - 1s - loss: 0.0056 - binary_accuracy: 0.9991 - val_loss: 1.0203 - val_binary_accuracy: 0.8381 - 506ms/epoch - 15ms/step
# Epoch 13/25
# 34/34 - 1s - loss: 0.0025 - binary_accuracy: 1.0000 - val_loss: 0.9767 - val_binary_accuracy: 0.8476 - 614ms/epoch - 18ms/step
# Epoch 14/25
# 34/34 - 1s - loss: 0.0019 - binary_accuracy: 1.0000 - val_loss: 0.9428 - val_binary_accuracy: 0.8438 - 652ms/epoch - 19ms/step
# Epoch 15/25
# 34/34 - 1s - loss: 0.0017 - binary_accuracy: 0.9991 - val_loss: 1.0251 - val_binary_accuracy: 0.8362 - 609ms/epoch - 18ms/step
# Epoch 16/25
# 34/34 - 1s - loss: 0.0028 - binary_accuracy: 0.9981 - val_loss: 0.9472 - val_binary_accuracy: 0.8343 - 599ms/epoch - 18ms/step
# Epoch 17/25
# 34/34 - 1s - loss: 8.1673e-04 - binary_accuracy: 1.0000 - val_loss: 1.0118 - val_binary_accuracy: 0.8362 - 522ms/epoch - 15ms/step
# Epoch 18/25
# 34/34 - 1s - loss: 4.2682e-04 - binary_accuracy: 1.0000 - val_loss: 1.1282 - val_binary_accuracy: 0.8362 - 550ms/epoch - 16ms/step
# Epoch 19/25
# 34/34 - 1s - loss: 7.6599e-04 - binary_accuracy: 1.0000 - val_loss: 1.1436 - val_binary_accuracy: 0.8381 - 530ms/epoch - 16ms/step
# Epoch 20/25
# 34/34 - 1s - loss: 4.4470e-04 - binary_accuracy: 1.0000 - val_loss: 1.0839 - val_binary_accuracy: 0.8381 - 650ms/epoch - 19ms/step
# Epoch 21/25
# 34/34 - 1s - loss: 7.2574e-04 - binary_accuracy: 1.0000 - val_loss: 1.0920 - val_binary_accuracy: 0.8419 - 532ms/epoch - 16ms/step
# Epoch 22/25
# 34/34 - 1s - loss: 4.9705e-04 - binary_accuracy: 1.0000 - val_loss: 1.1384 - val_binary_accuracy: 0.8438 - 556ms/epoch - 16ms/step
# Epoch 23/25
# 34/34 - 1s - loss: 3.7200e-04 - binary_accuracy: 1.0000 - val_loss: 1.1461 - val_binary_accuracy: 0.8419 - 553ms/epoch - 16ms/step
# Epoch 24/25
# 34/34 - 1s - loss: 2.1878e-04 - binary_accuracy: 1.0000 - val_loss: 1.2062 - val_binary_accuracy: 0.8438 - 552ms/epoch - 16ms/step
# Epoch 25/25
# 34/34 - 1s - loss: 1.3923e-04 - binary_accuracy: 1.0000 - val_loss: 1.1882 - val_binary_accuracy: 0.8419 - 517ms/epoch - 15ms/step

# %%
### Bidirectional LSTM Training
model1.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=25,batch_size=32, verbose = 2)
# Out:
# Epoch 1/25
# 34/34 - 1s - loss: 0.3432 - binary_accuracy: 0.8920 - val_loss: 0.3318 - val_binary_accuracy: 0.8743 - 770ms/epoch - 23ms/step
# Epoch 2/25
# 34/34 - 1s - loss: 0.1135 - binary_accuracy: 0.9643 - val_loss: 0.3903 - val_binary_accuracy: 0.8800 - 682ms/epoch - 20ms/step
# Epoch 3/25
# 34/34 - 1s - loss: 0.0388 - binary_accuracy: 0.9878 - val_loss: 0.4938 - val_binary_accuracy: 0.8781 - 689ms/epoch - 20ms/step
# Epoch 4/25
# 34/34 - 1s - loss: 0.0124 - binary_accuracy: 0.9972 - val_loss: 0.5986 - val_binary_accuracy: 0.8762 - 694ms/epoch - 20ms/step
# Epoch 5/25
# 34/34 - 1s - loss: 0.0122 - binary_accuracy: 0.9962 - val_loss: 0.5870 - val_binary_accuracy: 0.8667 - 687ms/epoch - 20ms/step
# Epoch 6/25
# 34/34 - 1s - loss: 0.0090 - binary_accuracy: 0.9972 - val_loss: 0.6501 - val_binary_accuracy: 0.8705 - 695ms/epoch - 20ms/step
# Epoch 7/25
# 34/34 - 1s - loss: 0.0050 - binary_accuracy: 0.9991 - val_loss: 0.7245 - val_binary_accuracy: 0.8686 - 690ms/epoch - 20ms/step
# Epoch 8/25
# 34/34 - 1s - loss: 0.0031 - binary_accuracy: 0.9991 - val_loss: 0.7403 - val_binary_accuracy: 0.8705 - 690ms/epoch - 20ms/step
# Epoch 9/25
# 34/34 - 1s - loss: 0.0023 - binary_accuracy: 0.9991 - val_loss: 0.8376 - val_binary_accuracy: 0.8648 - 685ms/epoch - 20ms/step
# Epoch 10/25
# 34/34 - 1s - loss: 0.0088 - binary_accuracy: 0.9972 - val_loss: 0.7110 - val_binary_accuracy: 0.8667 - 677ms/epoch - 20ms/step
# Epoch 11/25
# 34/34 - 1s - loss: 0.0053 - binary_accuracy: 0.9981 - val_loss: 0.7801 - val_binary_accuracy: 0.8648 - 689ms/epoch - 20ms/step
# Epoch 12/25
# 34/34 - 1s - loss: 0.0031 - binary_accuracy: 0.9991 - val_loss: 0.7778 - val_binary_accuracy: 0.8705 - 699ms/epoch - 21ms/step
# Epoch 13/25
# 34/34 - 1s - loss: 0.0053 - binary_accuracy: 0.9991 - val_loss: 0.8093 - val_binary_accuracy: 0.8743 - 733ms/epoch - 22ms/step
# Epoch 14/25
# 34/34 - 1s - loss: 0.0144 - binary_accuracy: 0.9972 - val_loss: 0.8263 - val_binary_accuracy: 0.8648 - 787ms/epoch - 23ms/step
# Epoch 15/25
# 34/34 - 1s - loss: 0.0278 - binary_accuracy: 0.9906 - val_loss: 0.6833 - val_binary_accuracy: 0.8590 - 698ms/epoch - 21ms/step
# Epoch 16/25
# 34/34 - 1s - loss: 0.0109 - binary_accuracy: 0.9972 - val_loss: 0.7324 - val_binary_accuracy: 0.8667 - 695ms/epoch - 20ms/step
# Epoch 17/25
# 34/34 - 1s - loss: 0.0074 - binary_accuracy: 0.9981 - val_loss: 0.7471 - val_binary_accuracy: 0.8552 - 806ms/epoch - 24ms/step
# Epoch 18/25
# 34/34 - 1s - loss: 0.0026 - binary_accuracy: 0.9991 - val_loss: 0.7876 - val_binary_accuracy: 0.8629 - 706ms/epoch - 21ms/step
# Epoch 19/25
# 34/34 - 1s - loss: 0.0016 - binary_accuracy: 1.0000 - val_loss: 0.8165 - val_binary_accuracy: 0.8571 - 870ms/epoch - 26ms/step
# Epoch 20/25
# 34/34 - 1s - loss: 0.0099 - binary_accuracy: 0.9953 - val_loss: 0.8057 - val_binary_accuracy: 0.8552 - 730ms/epoch - 21ms/step
# Epoch 21/25
# 34/34 - 1s - loss: 0.0033 - binary_accuracy: 0.9981 - val_loss: 0.7909 - val_binary_accuracy: 0.8533 - 767ms/epoch - 23ms/step
# Epoch 22/25
# 34/34 - 1s - loss: 0.0107 - binary_accuracy: 0.9981 - val_loss: 0.8899 - val_binary_accuracy: 0.8533 - 724ms/epoch - 21ms/step
# Epoch 23/25
# 34/34 - 1s - loss: 6.1276e-04 - binary_accuracy: 1.0000 - val_loss: 0.8981 - val_binary_accuracy: 0.8552 - 706ms/epoch - 21ms/step
# Epoch 24/25
# 34/34 - 1s - loss: 0.0042 - binary_accuracy: 0.9991 - val_loss: 0.7662 - val_binary_accuracy: 0.8343 - 706ms/epoch - 21ms/step
# Epoch 25/25
# 34/34 - 1s - loss: 0.0036 - binary_accuracy: 1.0000 - val_loss: 0.8766 - val_binary_accuracy: 0.8457 - 791ms/epoch - 23ms/step

# %% [markdown]
# ### Performance Metrics and Accuracy

# %% [markdown]
# ### LSTM

# %%
predictions = (model.predict(x_manual) > 0.5).astype("int32")

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_manual, predictions)
# Out:
# array([[5, 1],
#        [0, 4]])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_manual,predictions)
# Out:
# 0.9

# %%
from sklearn.metrics import classification_report
print(classification_report(y_manual, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.83      0.91         6
#            1       0.80      1.00      0.89         4
#
#     accuracy                           0.90        10
#    macro avg       0.90      0.92      0.90        10
# weighted avg       0.92      0.90      0.90        10

# %% [markdown]
# ### Bidirectional LSTM

# %%
predictions = (model.predict(x_manual) > 0.5).astype("int32")

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix(y_manual, predictions)
# Out:
# array([[5, 1],
#        [0, 4]])

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_manual,predictions)
# Out:
# 0.9

# %%
from sklearn.metrics import classification_report
print(classification_report(y_manual, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.83      0.91         6
#            1       0.80      1.00      0.89         4
#
#     accuracy                           0.90        10
#    macro avg       0.90      0.92      0.90        10
# weighted avg       0.92      0.90      0.90        10

# %% [markdown]
# ### Manual Testing

# %%
from nltk.stem.porter import PorterStemmer

def review_anaylsis(prediction):
    if prediction == 1:
        return "Honest Review"
    else:
        return "Fake Review"
    
def prediction(text):
    ps = PorterStemmer()
    corpus = []
    review = re.sub('[^a-zA-Z]', ' ', text)
    review = review.lower()
    review = review.split()
    review = [ps.stem(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    corpus.append(review)
    onehot_repr = [one_hot(words,voc_size)for words in corpus]
    sent_length=20
    embedded_docs=pad_sequences(onehot_repr,padding='pre',maxlen=sent_length)
    text_final = np.array(embedded_docs)
    lstm_prediction = (model.predict(text_final) > 0.5).astype("int32")
    bidr_prediction = (model1.predict(text_final) > 0.5).astype("int32")
    print(f"\n\nAccording to LSTM This review is a {review_anaylsis(lstm_prediction[0])}")
    print(f"\nAccording to Bidirectional LSTM This review is a {review_anaylsis(bidr_prediction[0])}")

# %%
text = str(input())
prediction(text)
# Out:
# "A very nice hotel with small but adequate rooms. The decor was lovely. My daughter and I spent 5-nights here, saw Wicked just down the street and used the public transportation to get all around town. Was a bit disappointed with the bar/restaurant which opened and closed it's kitchen at will without regard to posted hours. The room description boasted of safe's large enough to accomodate a laptop, so I brought mine. I was informed after check-in that the safes are not in every room (and not in mine). As a side note, I was surprised that nearly all the shops many restaurants closed at 6pm in that area... even the 7-11.  "
#
#
# According to LSTM This review is a Honest Review
#
# According to Bidirectional LSTM This review is a Honest Review
